# %% [markdown]
# #Pronóstico de fallas para mantenimiento predictivo usando metodologías de aprendizaje profundo supervisado
# ###Francisco Araya López - Departamento de Eléctronica - UTFSM
# ###Turbofan Engine Simulation Dataset
# ###Octubre 2020

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle
import random
import time

# %matplotlib inline

# %%
# PARAMETROS

#tamaño time windows de cada dataset
W_H_FD001 = 10 #MAX 30
W_H_FD002 = 10 #MAX 20
W_H_FD003 = 10 #MAX 30
W_H_FD004 = 10 #MAX 15
#Numero de features 
W_W_FDXXX = 14
#Semilla para generador numeros pseudoaleatorios // seed random number generator
SEED = 13
#Porcentaje datos entrenamiento respecto al total // percent training set
T_V_SPLIT = 0.9
# Optimizer

OPTIM = "Adam"

#HIPERPARAMETROS
BATCH_SIZE_T = 1024 #batch size all
EPOCHS_MAX = 250 #EPOCHS MAX

# %%
# window_h is the height of the sliding windows in the dataset
# window_w is the width of the sliding windows in the dataset
# seed is the seed of the random number generator used in shuffle function, for shuffle pairs (X,Y) before
# feed CNN in training process.
# t_v_split is the percentage of data used as training and the rest is used for validation data.

def build_train_and_test_set(path_train,path_test,path_rul,window_h,window_w,seed,t_v_split):
  
  #CREACION DE FEATURES MAPS Y RULS PARA ENTRENAMIENTO (Y VALIDACION) // Creacion matriz multidimensional de feature maps y vector de rul para entrenamiento (y validacion)

  df = pd.read_csv(path_train, sep = ' ', header = None)
  df = df.drop(columns=[26, 27])
  df.columns = (["n_engine","cycle","opset_1","opset_2","opset_3",
              "sens_1","sens_2","sens_3","sens_4","sens_5","sens_6","sens_7","sens_8","sens_9","sens_10",
              "sens_11","sens_12","sens_13","sens_14","sens_15","sens_16","sens_17","sens_18","sens_19","sens_20","sens_21"])
  df = df.drop(['sens_1','sens_5','sens_6','sens_10','sens_16','sens_18','sens_19'],axis=1)
  
  #Add RUL variable // Agregada variable RUL a df y normalización de columnas (salvo RUL)
  
  RUL_temp=np.zeros(0)
  for i in range(1,df['n_engine'].max() + 1):
    minus = np.linspace(1,df[df['n_engine']==i]['cycle'].max(),df[df['n_engine']==i]['cycle'].max())
    RUL_engine = np.ones((df[df['n_engine']==i]['cycle'].max()))*df[df['n_engine']==i]['cycle'].max()
    RUL_temp = np.append(RUL_temp,RUL_engine-minus)
  df['RUL'] = RUL_temp
  df['RUL'] = df['RUL'].astype(int)
  scaler = MinMaxScaler(feature_range=(-1,1))
  df[df.columns[1:19]]= scaler.fit_transform(df[df.columns[1:19]])

  #Feature maps creation // Creación de features maps
  features_maps=np.empty((window_h,window_w,1))
  df_ys = np.zeros((1,1))
  
  #se obtienen los dataset de engines independientes en df_temp
  for i in range(1,df['n_engine'].max()+1):
    df_temp1 = df[df['n_engine'] == i]
    df_temp2 = df_temp1.drop(['n_engine','cycle','opset_1','opset_2','opset_3'],axis=1)
    df_features = df_temp2.drop(['RUL'],axis = 1)
    df_y = df_temp2['RUL'].to_numpy()
    df_ys = np.append(df_ys,df_y[(window_h - 1):])
    for j in range(len(df_y)-(window_h - 1)):
      feature_map = df_features[j:j+(window_h)][:]
      features_maps = np.dstack((features_maps, feature_map))
  features_maps=np.delete(features_maps, 0, 2)
  df_ys = np.delete(df_ys, 0, 0)
  
  # change of dimension order // cambio de dimensión features maps de forma Ntimestaps,Nfeatures,M) a (M,Ntimestaps,Nfeatures)
  features_maps = np.moveaxis(features_maps, 2, 0)

  # Expansion a 2 dimensiones para vector con Yverdaderos (RUL conjunto de entrenamiento) y 4 para features maps
  df_ys = np.expand_dims(df_ys,axis=1)
  features_maps= np.expand_dims(features_maps,3)

  #random para pares (X,Y) del conjunto de entrenamiento
  features_maps, df_ys = shuffle(features_maps, df_ys, random_state=seed)

  #valores de RUL mayores a 120 se seteean en 120
  for i in range(len(df_ys)):
    if df_ys[i] >= 120:
      df_ys[i] = 120

  ys_train = df_ys[:int(len(df_ys)*(t_v_split))]
  ys_valid = df_ys[int(len(df_ys)*(t_v_split)):]

  features_maps_train = features_maps[:int(len(df_ys)*(t_v_split))]
  features_maps_valid = features_maps[int(len(df_ys)*(t_v_split)):]

  #CREACION DE FEATURES MAPS Y RULS PARA TESTEO

  df_t = pd.read_csv(path_test, sep = ' ', header = None)
  df_t = df_t.drop(columns=[26, 27])
  df_t.columns = (["n_engine","cycle","opset_1","opset_2","opset_3",
              "sens_1","sens_2","sens_3","sens_4","sens_5","sens_6","sens_7","sens_8","sens_9","sens_10",
              "sens_11","sens_12","sens_13","sens_14","sens_15","sens_16","sens_17","sens_18","sens_19","sens_20","sens_21"])
  df_t = df_t.drop(['sens_1','sens_5','sens_6','sens_10','sens_16','sens_18','sens_19'],axis=1)
  df_t[df_t.columns[1:19]]= scaler.transform(df_t[df_t.columns[1:19]])

  #se obtienen los dataset de engines independientes en df_temp
  features_maps_test=np.empty((window_h,window_w,1))
  for i in range(1,df_t['n_engine'].max()+1):
    df_temp = df_t[df_t['n_engine'] == i].drop(['n_engine','cycle','opset_1','opset_2','opset_3'],axis=1)
    df_large = df_temp['sens_8'].count()
    feature_map = df_temp[df_large-(window_h):][:]
    features_maps_test = np.dstack((features_maps_test, feature_map))
  features_maps_test=np.delete(features_maps_test, 0, 2)
  
  # cambio de dimensión features maps de forma Ntimestaps,Nfeatures,M) a (M,Ntimestaps,Nfeatures)
  features_maps_test = np.moveaxis(features_maps_test, 2, 0)
  features_maps_test = np.expand_dims(features_maps_test,3)

  ruls_test= []
  rul_file = open(path_rul, "r")
  for rul_line in rul_file:
    ruls_test.append(int(rul_line.rstrip(' \n')))

  ruls_test_final = np.array(ruls_test)
  features_maps_test_final = np.array(features_maps_test)
  idx   = np.argsort(ruls_test_final)

  ruls_test_final = np.array(ruls_test_final)[idx]
  features_maps_test_final = np.array(features_maps_test_final)[idx]

  for i in range(len(ruls_test_final)):
    if ruls_test_final[i] >= 120:
      ruls_test_final[i] = 120

  return ys_train, ys_valid, features_maps_train, features_maps_valid, ruls_test_final, features_maps_test_final

# %%
y_train1, y_valid1, f_maps_train1, f_maps_valid1, r_test_f1, f_maps_test_f1 = (build_train_and_test_set('train_FD001.txt','test_FD001.txt','RUL_FD001.txt',W_H_FD001,W_W_FDXXX,SEED,T_V_SPLIT))

# %%
y_train2, y_valid2, f_maps_train2, f_maps_valid2, r_test_f2, f_maps_test_f2 = (build_train_and_test_set('train_FD002.txt','test_FD002.txt','RUL_FD002.txt',W_H_FD002,W_W_FDXXX,SEED,T_V_SPLIT))

# %%
y_train3, y_valid3, f_maps_train3, f_maps_valid3, r_test_f3, f_maps_test_f3 = (build_train_and_test_set('train_FD003.txt','test_FD003.txt','RUL_FD003.txt',W_H_FD003,W_W_FDXXX,SEED,T_V_SPLIT))

# %%
y_train4, y_valid4, f_maps_train4, f_maps_valid4, r_test_f4, f_maps_test_f4 = (build_train_and_test_set('train_FD004.txt','test_FD004.txt','RUL_FD004.txt',W_H_FD004,W_W_FDXXX,SEED,T_V_SPLIT))

# %%
#Union de datasets

#FD001+FD003
f_maps_train13 = np.append(f_maps_train1,f_maps_train3,axis=0)
f_maps_valid13 = np.append(f_maps_valid1,f_maps_valid3,axis=0)
f_maps_13 = np.append(f_maps_train13,f_maps_valid13,axis=0)
print(f_maps_13.shape)
y_train13 = np.append(y_train1,y_train3,axis=0)
y_valid13 = np.append(y_valid1,y_valid3,axis=0)
y_13 = np.append(y_train13,y_valid13,axis=0)
print(y_13.shape)
f_maps_test_f1f3 = np.append(f_maps_test_f1,f_maps_test_f3,axis=0)
r_test_f1f3 = np.append(r_test_f1,r_test_f3)
print(f_maps_test_f1f3.shape)
print(r_test_f1f3.shape)

#FD002+FD004

f_maps_train24 = np.append(f_maps_train2,f_maps_train4,axis=0)
f_maps_valid24 = np.append(f_maps_valid2,f_maps_valid4,axis=0)
f_maps_24 = np.append(f_maps_train24,f_maps_valid24,axis=0)
print(f_maps_24.shape)
y_train24 = np.append(y_train2,y_train4,axis=0)
y_valid24 = np.append(y_valid2,y_valid4,axis=0)
y_24 = np.append(y_train24,y_valid24,axis=0)
print(y_24.shape)
f_maps_test_f2f4 = np.append(f_maps_test_f2,f_maps_test_f4,axis=0)
r_test_f2f4 = np.append(r_test_f2,r_test_f4)
print(f_maps_test_f2f4.shape)
print(r_test_f2f4.shape)
# Out:
# (43551, 10, 14, 1)
# (43551, 1)
# (200, 10, 14, 1)
# (200,)
# (110427, 10, 14, 1)
# (110427, 1)
# (507, 10, 14, 1)
# (507,)

# %%
#Ordenamiento menor a mayor por RUL pares (X,Y) test set

idx   = np.argsort(r_test_f1f3)
r_test_f1f3 = np.array(r_test_f1f3)[idx]
f_maps_test_f1f3 = np.array(f_maps_test_f1f3)[idx]


idx2   = np.argsort(r_test_f2f4)
r_test_f2f4 = np.array(r_test_f2f4)[idx2]
f_maps_test_f2f4 = np.array(f_maps_test_f2f4)[idx2]

# %% [markdown]
# # CNN
#
# Arquitectura propuesta basada en G. Babu, P. Zhao, X.-L. Li, Deep Convolutional Neural Network Based Regression Approach for Estimation of Remaining Useful Life

# %% [markdown]
# ![cnn2.png](data:image/png;base64,...)

# %%
from keras import layers
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.models import Model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
from keras import regularizers

import keras.backend as K
K.set_image_data_format('channels_last')

# %% [markdown]
# Arquitectura propuesta a continuación:
#
# ![CNN_BABU.png](data:image/png;base64,...)

# %%
def cnnturbofan(input_shape):
   
    X_input = Input(input_shape)

    # CONV -> TANH aplicado a X
    X = Conv2D(8, (4, 14), strides = (1, 1),padding='same', name = 'conv0')(X_input)
    #X = BatchNormalization(axis = 3, name = 'bn0')(X)
    X = Activation('sigmoid')(X)

    #Layer 2

    X = AveragePooling2D(pool_size=(2,1))(X)
    #X = BatchNormalization(axis = 3, name = 'bn1')(X)

    #Layer 3

    X = Conv2D(14, (3, 1), strides = (1, 1), padding='same', name = 'conv1')(X)
    #X = BatchNormalization(axis = 3, name = 'bn2')(X)
    X = Activation('sigmoid')(X)

    #Layer 4

    X = AveragePooling2D(pool_size=(2,1))(X)
    #X = BatchNormalization(axis = 3, name = 'bn3')(X)


    # FLATTEN X ("desenrollamos el feature map anterior") + FULLYCONNECTED
    X = Flatten()(X)
    X = Dropout(0.5)(X)
    #X = BatchNormalization(name='bn5')(X)
    X = Dense(1024, activation='sigmoid', name='fully-connected')(X)
    X = Dropout(0.5)(X)
    #X = BatchNormalization(name='bn6')(X)
    X = Dense(1, name = 'rul-neuron')(X)

    # instancia modelo final
    model = Model(inputs = X_input, outputs = X, name='cnnturbofan')
    
  
    return model

# %%
cnnturbofan = cnnturbofan(((f_maps_13.shape[1]),(f_maps_13.shape[2]),(f_maps_13.shape[3])))

# %%
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true))) 

cnnturbofan.compile(optimizer = "Adam", loss = "mean_squared_error" , metrics = [root_mean_squared_error])

# %%
history = cnnturbofan.fit(x = f_maps_13, y = y_13 ,batch_size=BATCH_SIZE_T, epochs = EPOCHS_MAX ,validation_split=0.1)
# Out:
# Epoch 1/250
# 39/39 [==============================] - 0s 11ms/step - loss: 5446.1948 - root_mean_squared_error: 72.9258 - val_loss: 3655.3926 - val_root_mean_squared_error: 61.0763
# Epoch 2/250
# 39/39 [==============================] - 0s 5ms/step - loss: 2847.8171 - root_mean_squared_error: 53.1134 - val_loss: 2214.3125 - val_root_mean_squared_error: 47.4105
# Epoch 3/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1915.2761 - root_mean_squared_error: 43.6961 - val_loss: 1699.1079 - val_root_mean_squared_error: 41.2690
# Epoch 4/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1637.3073 - root_mean_squared_error: 40.4760 - val_loss: 1578.3470 - val_root_mean_squared_error: 39.5651
# Epoch 5/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1586.1398 - root_mean_squared_error: 39.7955 - val_loss: 1559.6366 - val_root_mean_squared_error: 39.2363
# Epoch 6/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1578.4698 - root_mean_squared_error: 39.7210 - val_loss: 1557.2782 - val_root_mean_squared_error: 39.1774
# Epoch 7/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1580.8331 - root_mean_squared_error: 39.7427 - val_loss: 1556.8917 - val_root_mean_squared_error: 39.1672
# Epoch 8/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1575.6895 - root_mean_squared_error: 39.7138 - val_loss: 1556.6443 - val_root_mean_squared_error: 39.1634
# Epoch 9/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1576.8323 - root_mean_squared_error: 39.6867 - val_loss: 1556.2795 - val_root_mean_squared_error: 39.1603
# Epoch 10/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1578.5859 - root_mean_squared_error: 39.7041 - val_loss: 1555.4260 - val_root_mean_squared_error: 39.1479
# Epoch 11/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1575.0164 - root_mean_squared_error: 39.7054 - val_loss: 1553.6846 - val_root_mean_squared_error: 39.1243
# Epoch 12/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1575.4656 - root_mean_squared_error: 39.6443 - val_loss: 1548.8896 - val_root_mean_squared_error: 39.0661
# Epoch 13/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1564.2899 - root_mean_squared_error: 39.5441 - val_loss: 1529.2289 - val_root_mean_squared_error: 38.8010
# Epoch 14/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1517.8340 - root_mean_squared_error: 38.9280 - val_loss: 1421.0153 - val_root_mean_squared_error: 37.4173
# Epoch 15/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1269.9197 - root_mean_squared_error: 35.5046 - val_loss: 993.1348 - val_root_mean_squared_error: 31.1795
# Epoch 16/250
# 39/39 [==============================] - 0s 5ms/step - loss: 811.6850 - root_mean_squared_error: 28.3093 - val_loss: 570.9413 - val_root_mean_squared_error: 23.6011
# Epoch 17/250
# 39/39 [==============================] - 0s 5ms/step - loss: 503.0735 - root_mean_squared_error: 22.3717 - val_loss: 408.1451 - val_root_mean_squared_error: 20.0504
# Epoch 18/250
# 39/39 [==============================] - 0s 5ms/step - loss: 425.4465 - root_mean_squared_error: 20.5933 - val_loss: 382.6633 - val_root_mean_squared_error: 19.2863
# Epoch 19/250
# 39/39 [==============================] - 0s 5ms/step - loss: 403.1910 - root_mean_squared_error: 20.0889 - val_loss: 366.6812 - val_root_mean_squared_error: 18.8824
# Epoch 20/250
# 39/39 [==============================] - 0s 5ms/step - loss: 391.0067 - root_mean_squared_error: 19.7616 - val_loss: 356.2997 - val_root_mean_squared_error: 18.6078
# Epoch 21/250
# 39/39 [==============================] - 0s 5ms/step - loss: 380.0240 - root_mean_squared_error: 19.4577 - val_loss: 349.1911 - val_root_mean_squared_error: 18.3923
# Epoch 22/250
# 39/39 [==============================] - 0s 5ms/step - loss: 373.6624 - root_mean_squared_error: 19.3199 - val_loss: 344.2028 - val_root_mean_squared_error: 18.2333
# Epoch 23/250
# 39/39 [==============================] - 0s 5ms/step - loss: 368.1577 - root_mean_squared_error: 19.1870 - val_loss: 338.0336 - val_root_mean_squared_error: 18.0963
# Epoch 24/250
# 39/39 [==============================] - 0s 5ms/step - loss: 364.1154 - root_mean_squared_error: 19.0844 - val_loss: 335.8425 - val_root_mean_squared_error: 17.9970
# Epoch 25/250
# 39/39 [==============================] - 0s 5ms/step - loss: 357.7243 - root_mean_squared_error: 18.9047 - val_loss: 331.1913 - val_root_mean_squared_error: 17.8845
# Epoch 26/250
# 39/39 [==============================] - 0s 5ms/step - loss: 355.1278 - root_mean_squared_error: 18.8255 - val_loss: 328.7195 - val_root_mean_squared_error: 17.8100
# Epoch 27/250
# 39/39 [==============================] - 0s 5ms/step - loss: 352.3504 - root_mean_squared_error: 18.7502 - val_loss: 326.0339 - val_root_mean_squared_error: 17.7521
# Epoch 28/250
# 39/39 [==============================] - 0s 5ms/step - loss: 348.9901 - root_mean_squared_error: 18.6569 - val_loss: 324.0482 - val_root_mean_squared_error: 17.6950
# Epoch 29/250
# 39/39 [==============================] - 0s 5ms/step - loss: 348.6794 - root_mean_squared_error: 18.6822 - val_loss: 322.5718 - val_root_mean_squared_error: 17.6546
# Epoch 30/250
# 39/39 [==============================] - 0s 5ms/step - loss: 344.5918 - root_mean_squared_error: 18.5504 - val_loss: 320.7793 - val_root_mean_squared_error: 17.6018
# Epoch 31/250
# 39/39 [==============================] - 0s 5ms/step - loss: 343.1846 - root_mean_squared_error: 18.4953 - val_loss: 320.4312 - val_root_mean_squared_error: 17.5831
# Epoch 32/250
# 39/39 [==============================] - 0s 5ms/step - loss: 342.8278 - root_mean_squared_error: 18.4949 - val_loss: 318.9294 - val_root_mean_squared_error: 17.5371
# Epoch 33/250
# 39/39 [==============================] - 0s 5ms/step - loss: 339.7755 - root_mean_squared_error: 18.4027 - val_loss: 317.6238 - val_root_mean_squared_error: 17.5273
# Epoch 34/250
# 39/39 [==============================] - 0s 5ms/step - loss: 339.7994 - root_mean_squared_error: 18.4447 - val_loss: 316.6977 - val_root_mean_squared_error: 17.4973
# Epoch 35/250
# 39/39 [==============================] - 0s 5ms/step - loss: 337.4886 - root_mean_squared_error: 18.3870 - val_loss: 315.0118 - val_root_mean_squared_error: 17.4450
# Epoch 36/250
# 39/39 [==============================] - 0s 5ms/step - loss: 335.8549 - root_mean_squared_error: 18.3031 - val_loss: 314.3260 - val_root_mean_squared_error: 17.4313
# Epoch 37/250
# 39/39 [==============================] - 0s 5ms/step - loss: 334.6933 - root_mean_squared_error: 18.2867 - val_loss: 313.5852 - val_root_mean_squared_error: 17.4012
# Epoch 38/250
# 39/39 [==============================] - 0s 5ms/step - loss: 334.3785 - root_mean_squared_error: 18.2952 - val_loss: 312.6224 - val_root_mean_squared_error: 17.3891
# Epoch 39/250
# 39/39 [==============================] - 0s 5ms/step - loss: 331.0143 - root_mean_squared_error: 18.1654 - val_loss: 311.6295 - val_root_mean_squared_error: 17.3494
# Epoch 40/250
# 39/39 [==============================] - 0s 5ms/step - loss: 332.7287 - root_mean_squared_error: 18.2355 - val_loss: 310.6732 - val_root_mean_squared_error: 17.3201
# Epoch 41/250
# 39/39 [==============================] - 0s 5ms/step - loss: 329.9954 - root_mean_squared_error: 18.1536 - val_loss: 309.7888 - val_root_mean_squared_error: 17.3045
# Epoch 42/250
# 39/39 [==============================] - 0s 5ms/step - loss: 328.6953 - root_mean_squared_error: 18.1218 - val_loss: 308.9558 - val_root_mean_squared_error: 17.2817
# Epoch 43/250
# 39/39 [==============================] - 0s 5ms/step - loss: 326.9690 - root_mean_squared_error: 18.0654 - val_loss: 308.1085 - val_root_mean_squared_error: 17.2601
# Epoch 44/250
# 39/39 [==============================] - 0s 5ms/step - loss: 327.0161 - root_mean_squared_error: 18.0900 - val_loss: 307.7148 - val_root_mean_squared_error: 17.2422
# Epoch 45/250
# 39/39 [==============================] - 0s 5ms/step - loss: 322.2716 - root_mean_squared_error: 17.9348 - val_loss: 308.0322 - val_root_mean_squared_error: 17.2354
# Epoch 46/250
# 39/39 [==============================] - 0s 5ms/step - loss: 323.8113 - root_mean_squared_error: 17.9911 - val_loss: 305.4367 - val_root_mean_squared_error: 17.1818
# Epoch 47/250
# 39/39 [==============================] - 0s 5ms/step - loss: 322.1483 - root_mean_squared_error: 17.9344 - val_loss: 305.3387 - val_root_mean_squared_error: 17.1689
# Epoch 48/250
# 39/39 [==============================] - 0s 5ms/step - loss: 322.0671 - root_mean_squared_error: 17.9251 - val_loss: 304.3804 - val_root_mean_squared_error: 17.1444
# Epoch 49/250
# 39/39 [==============================] - 0s 5ms/step - loss: 320.7197 - root_mean_squared_error: 17.9134 - val_loss: 304.2704 - val_root_mean_squared_error: 17.1335
# Epoch 50/250
# 39/39 [==============================] - 0s 5ms/step - loss: 319.8505 - root_mean_squared_error: 17.8430 - val_loss: 303.8173 - val_root_mean_squared_error: 17.1229
# Epoch 51/250
# 39/39 [==============================] - 0s 5ms/step - loss: 318.7475 - root_mean_squared_error: 17.8650 - val_loss: 302.4272 - val_root_mean_squared_error: 17.0906
# Epoch 52/250
# 39/39 [==============================] - 0s 5ms/step - loss: 317.5263 - root_mean_squared_error: 17.7977 - val_loss: 301.3736 - val_root_mean_squared_error: 17.0721
# Epoch 53/250
# 39/39 [==============================] - 0s 5ms/step - loss: 318.1493 - root_mean_squared_error: 17.8229 - val_loss: 301.1429 - val_root_mean_squared_error: 17.0657
# Epoch 54/250
# 39/39 [==============================] - 0s 5ms/step - loss: 316.0675 - root_mean_squared_error: 17.7661 - val_loss: 301.9496 - val_root_mean_squared_error: 17.0602
# Epoch 55/250
# 39/39 [==============================] - 0s 5ms/step - loss: 315.0724 - root_mean_squared_error: 17.7589 - val_loss: 299.9599 - val_root_mean_squared_error: 17.0175
# Epoch 56/250
# 39/39 [==============================] - 0s 5ms/step - loss: 315.7503 - root_mean_squared_error: 17.7276 - val_loss: 299.3587 - val_root_mean_squared_error: 16.9987
# Epoch 57/250
# 39/39 [==============================] - 0s 5ms/step - loss: 314.9978 - root_mean_squared_error: 17.7427 - val_loss: 298.7934 - val_root_mean_squared_error: 16.9935
# Epoch 58/250
# 39/39 [==============================] - 0s 5ms/step - loss: 313.5038 - root_mean_squared_error: 17.7245 - val_loss: 298.4385 - val_root_mean_squared_error: 16.9775
# Epoch 59/250
# 39/39 [==============================] - 0s 5ms/step - loss: 313.9003 - root_mean_squared_error: 17.7171 - val_loss: 297.7338 - val_root_mean_squared_error: 16.9583
# Epoch 60/250
# 39/39 [==============================] - 0s 5ms/step - loss: 314.0365 - root_mean_squared_error: 17.6941 - val_loss: 297.5948 - val_root_mean_squared_error: 16.9618
# Epoch 61/250
# 39/39 [==============================] - 0s 5ms/step - loss: 311.8711 - root_mean_squared_error: 17.6566 - val_loss: 297.1834 - val_root_mean_squared_error: 16.9328
# Epoch 62/250
# 39/39 [==============================] - 0s 5ms/step - loss: 310.9578 - root_mean_squared_error: 17.6459 - val_loss: 296.5039 - val_root_mean_squared_error: 16.9227
# Epoch 63/250
# 39/39 [==============================] - 0s 5ms/step - loss: 311.2822 - root_mean_squared_error: 17.6460 - val_loss: 296.3118 - val_root_mean_squared_error: 16.9100
# Epoch 64/250
# 39/39 [==============================] - 0s 5ms/step - loss: 310.8963 - root_mean_squared_error: 17.6284 - val_loss: 295.6303 - val_root_mean_squared_error: 16.8969
# Epoch 65/250
# 39/39 [==============================] - 0s 5ms/step - loss: 310.1305 - root_mean_squared_error: 17.6218 - val_loss: 295.9399 - val_root_mean_squared_error: 16.9069
# Epoch 66/250
# 39/39 [==============================] - 0s 5ms/step - loss: 308.6792 - root_mean_squared_error: 17.5686 - val_loss: 295.1981 - val_root_mean_squared_error: 16.8817
# Epoch 67/250
# 39/39 [==============================] - 0s 5ms/step - loss: 309.7493 - root_mean_squared_error: 17.5672 - val_loss: 296.0415 - val_root_mean_squared_error: 16.8904
# Epoch 68/250
# 39/39 [==============================] - 0s 5ms/step - loss: 308.0652 - root_mean_squared_error: 17.5197 - val_loss: 294.5123 - val_root_mean_squared_error: 16.8748
# Epoch 69/250
# 39/39 [==============================] - 0s 5ms/step - loss: 307.8701 - root_mean_squared_error: 17.5713 - val_loss: 294.1825 - val_root_mean_squared_error: 16.8578
# Epoch 70/250
# 39/39 [==============================] - 0s 5ms/step - loss: 307.7703 - root_mean_squared_error: 17.4979 - val_loss: 293.9321 - val_root_mean_squared_error: 16.8458
# Epoch 71/250
# 39/39 [==============================] - 0s 5ms/step - loss: 307.2101 - root_mean_squared_error: 17.5064 - val_loss: 293.8555 - val_root_mean_squared_error: 16.8332
# Epoch 72/250
# 39/39 [==============================] - 0s 5ms/step - loss: 306.3713 - root_mean_squared_error: 17.4826 - val_loss: 293.3626 - val_root_mean_squared_error: 16.8264
# Epoch 73/250
# 39/39 [==============================] - 0s 5ms/step - loss: 306.4225 - root_mean_squared_error: 17.5069 - val_loss: 292.9697 - val_root_mean_squared_error: 16.8188
# Epoch 74/250
# 39/39 [==============================] - 0s 5ms/step - loss: 306.5770 - root_mean_squared_error: 17.5368 - val_loss: 292.6222 - val_root_mean_squared_error: 16.8033
# Epoch 75/250
# 39/39 [==============================] - 0s 5ms/step - loss: 307.7440 - root_mean_squared_error: 17.5315 - val_loss: 292.2760 - val_root_mean_squared_error: 16.7966
# Epoch 76/250
# 39/39 [==============================] - 0s 5ms/step - loss: 305.2620 - root_mean_squared_error: 17.4478 - val_loss: 292.2262 - val_root_mean_squared_error: 16.7897
# Epoch 77/250
# 39/39 [==============================] - 0s 5ms/step - loss: 305.7101 - root_mean_squared_error: 17.4525 - val_loss: 291.7363 - val_root_mean_squared_error: 16.7772
# Epoch 78/250
# 39/39 [==============================] - 0s 5ms/step - loss: 303.7026 - root_mean_squared_error: 17.4040 - val_loss: 291.8787 - val_root_mean_squared_error: 16.7713
# Epoch 79/250
# 39/39 [==============================] - 0s 5ms/step - loss: 304.4961 - root_mean_squared_error: 17.4555 - val_loss: 291.5696 - val_root_mean_squared_error: 16.7617
# Epoch 80/250
# 39/39 [==============================] - 0s 5ms/step - loss: 303.6819 - root_mean_squared_error: 17.4044 - val_loss: 290.8961 - val_root_mean_squared_error: 16.7501
# Epoch 81/250
# 39/39 [==============================] - 0s 5ms/step - loss: 303.4355 - root_mean_squared_error: 17.4096 - val_loss: 290.9336 - val_root_mean_squared_error: 16.7791
# Epoch 82/250
# 39/39 [==============================] - 0s 5ms/step - loss: 302.2995 - root_mean_squared_error: 17.3756 - val_loss: 290.1618 - val_root_mean_squared_error: 16.7329
# Epoch 83/250
# 39/39 [==============================] - 0s 5ms/step - loss: 301.0615 - root_mean_squared_error: 17.3645 - val_loss: 290.2497 - val_root_mean_squared_error: 16.7434
# Epoch 84/250
# 39/39 [==============================] - 0s 5ms/step - loss: 302.0318 - root_mean_squared_error: 17.3527 - val_loss: 289.9872 - val_root_mean_squared_error: 16.7239
# Epoch 85/250
# 39/39 [==============================] - 0s 5ms/step - loss: 301.7133 - root_mean_squared_error: 17.3613 - val_loss: 289.7128 - val_root_mean_squared_error: 16.7161
# Epoch 86/250
# 39/39 [==============================] - 0s 5ms/step - loss: 300.9492 - root_mean_squared_error: 17.3362 - val_loss: 289.3071 - val_root_mean_squared_error: 16.7136
# Epoch 87/250
# 39/39 [==============================] - 0s 5ms/step - loss: 299.9008 - root_mean_squared_error: 17.3256 - val_loss: 289.8188 - val_root_mean_squared_error: 16.7113
# Epoch 88/250
# 39/39 [==============================] - 0s 5ms/step - loss: 301.0139 - root_mean_squared_error: 17.3044 - val_loss: 288.7733 - val_root_mean_squared_error: 16.7040
# Epoch 89/250
# 39/39 [==============================] - 0s 5ms/step - loss: 300.8678 - root_mean_squared_error: 17.3479 - val_loss: 288.9644 - val_root_mean_squared_error: 16.6927
# Epoch 90/250
# 39/39 [==============================] - 0s 5ms/step - loss: 300.9570 - root_mean_squared_error: 17.3401 - val_loss: 288.4120 - val_root_mean_squared_error: 16.6873
# Epoch 91/250
# 39/39 [==============================] - 0s 5ms/step - loss: 299.6741 - root_mean_squared_error: 17.3024 - val_loss: 287.9476 - val_root_mean_squared_error: 16.6689
# Epoch 92/250
# 39/39 [==============================] - 0s 5ms/step - loss: 299.8905 - root_mean_squared_error: 17.3227 - val_loss: 288.0623 - val_root_mean_squared_error: 16.6601
# Epoch 93/250
# 39/39 [==============================] - 0s 5ms/step - loss: 299.2618 - root_mean_squared_error: 17.2596 - val_loss: 289.1391 - val_root_mean_squared_error: 16.6820
# Epoch 94/250
# 39/39 [==============================] - 0s 5ms/step - loss: 298.1313 - root_mean_squared_error: 17.2725 - val_loss: 287.4179 - val_root_mean_squared_error: 16.6486
# Epoch 95/250
# 39/39 [==============================] - 0s 5ms/step - loss: 297.3767 - root_mean_squared_error: 17.2285 - val_loss: 287.1082 - val_root_mean_squared_error: 16.6359
# Epoch 96/250
# 39/39 [==============================] - 0s 5ms/step - loss: 298.6965 - root_mean_squared_error: 17.3183 - val_loss: 287.6090 - val_root_mean_squared_error: 16.6428
# Epoch 97/250
# 39/39 [==============================] - 0s 5ms/step - loss: 297.3891 - root_mean_squared_error: 17.2182 - val_loss: 286.9660 - val_root_mean_squared_error: 16.6269
# Epoch 98/250
# 39/39 [==============================] - 0s 5ms/step - loss: 299.8115 - root_mean_squared_error: 17.3046 - val_loss: 286.1479 - val_root_mean_squared_error: 16.6242
# Epoch 99/250
# 39/39 [==============================] - 0s 5ms/step - loss: 296.4599 - root_mean_squared_error: 17.2226 - val_loss: 286.0419 - val_root_mean_squared_error: 16.6113
# Epoch 100/250
# 39/39 [==============================] - 0s 5ms/step - loss: 296.1261 - root_mean_squared_error: 17.2197 - val_loss: 285.9190 - val_root_mean_squared_error: 16.6064
# Epoch 101/250
# 39/39 [==============================] - 0s 5ms/step - loss: 296.7412 - root_mean_squared_error: 17.2177 - val_loss: 286.3321 - val_root_mean_squared_error: 16.6079
# Epoch 102/250
# 39/39 [==============================] - 0s 5ms/step - loss: 296.7061 - root_mean_squared_error: 17.2214 - val_loss: 285.9615 - val_root_mean_squared_error: 16.5929
# Epoch 103/250
# 39/39 [==============================] - 0s 5ms/step - loss: 296.0842 - root_mean_squared_error: 17.1951 - val_loss: 286.2285 - val_root_mean_squared_error: 16.6364
# Epoch 104/250
# 39/39 [==============================] - 0s 5ms/step - loss: 296.1072 - root_mean_squared_error: 17.2421 - val_loss: 285.1684 - val_root_mean_squared_error: 16.5847
# Epoch 105/250
# 39/39 [==============================] - 0s 5ms/step - loss: 294.5657 - root_mean_squared_error: 17.1736 - val_loss: 284.9905 - val_root_mean_squared_error: 16.5780
# Epoch 106/250
# 39/39 [==============================] - 0s 5ms/step - loss: 297.3744 - root_mean_squared_error: 17.2187 - val_loss: 285.5220 - val_root_mean_squared_error: 16.5796
# Epoch 107/250
# 39/39 [==============================] - 0s 5ms/step - loss: 294.0553 - root_mean_squared_error: 17.1440 - val_loss: 284.2607 - val_root_mean_squared_error: 16.5693
# Epoch 108/250
# 39/39 [==============================] - 0s 5ms/step - loss: 294.4096 - root_mean_squared_error: 17.1446 - val_loss: 286.1192 - val_root_mean_squared_error: 16.5884
# Epoch 109/250
# 39/39 [==============================] - 0s 5ms/step - loss: 293.4176 - root_mean_squared_error: 17.1083 - val_loss: 283.8359 - val_root_mean_squared_error: 16.5410
# Epoch 110/250
# 39/39 [==============================] - 0s 5ms/step - loss: 293.3690 - root_mean_squared_error: 17.1100 - val_loss: 283.4936 - val_root_mean_squared_error: 16.5352
# Epoch 111/250
# 39/39 [==============================] - 0s 5ms/step - loss: 293.4005 - root_mean_squared_error: 17.1256 - val_loss: 284.4438 - val_root_mean_squared_error: 16.5785
# Epoch 112/250
# 39/39 [==============================] - 0s 5ms/step - loss: 292.7689 - root_mean_squared_error: 17.0603 - val_loss: 283.6553 - val_root_mean_squared_error: 16.5282
# Epoch 113/250
# 39/39 [==============================] - 0s 5ms/step - loss: 293.5229 - root_mean_squared_error: 17.1334 - val_loss: 283.2615 - val_root_mean_squared_error: 16.5170
# Epoch 114/250
# 39/39 [==============================] - 0s 5ms/step - loss: 293.9615 - root_mean_squared_error: 17.1495 - val_loss: 282.6096 - val_root_mean_squared_error: 16.5022
# Epoch 115/250
# 39/39 [==============================] - 0s 5ms/step - loss: 292.3491 - root_mean_squared_error: 17.1358 - val_loss: 282.7301 - val_root_mean_squared_error: 16.5034
# Epoch 116/250
# 39/39 [==============================] - 0s 5ms/step - loss: 290.9624 - root_mean_squared_error: 17.0299 - val_loss: 282.9875 - val_root_mean_squared_error: 16.5092
# Epoch 117/250
# 39/39 [==============================] - 0s 5ms/step - loss: 291.0086 - root_mean_squared_error: 17.0525 - val_loss: 281.9880 - val_root_mean_squared_error: 16.5015
# Epoch 118/250
# 39/39 [==============================] - 0s 5ms/step - loss: 293.3959 - root_mean_squared_error: 17.1192 - val_loss: 281.9478 - val_root_mean_squared_error: 16.4854
# Epoch 119/250
# 39/39 [==============================] - 0s 5ms/step - loss: 294.0586 - root_mean_squared_error: 17.1477 - val_loss: 281.7061 - val_root_mean_squared_error: 16.4979
# Epoch 120/250
# 39/39 [==============================] - 0s 5ms/step - loss: 292.6300 - root_mean_squared_error: 17.0925 - val_loss: 283.7083 - val_root_mean_squared_error: 16.5229
# Epoch 121/250
# 39/39 [==============================] - 0s 5ms/step - loss: 291.3173 - root_mean_squared_error: 17.0490 - val_loss: 281.5012 - val_root_mean_squared_error: 16.4695
# Epoch 122/250
# 39/39 [==============================] - 0s 5ms/step - loss: 291.8593 - root_mean_squared_error: 17.0765 - val_loss: 281.0138 - val_root_mean_squared_error: 16.4652
# Epoch 123/250
# 39/39 [==============================] - 0s 5ms/step - loss: 292.0842 - root_mean_squared_error: 17.0766 - val_loss: 280.9224 - val_root_mean_squared_error: 16.4585
# Epoch 124/250
# 39/39 [==============================] - 0s 5ms/step - loss: 291.7350 - root_mean_squared_error: 17.0902 - val_loss: 281.0218 - val_root_mean_squared_error: 16.4584
# Epoch 125/250
# 39/39 [==============================] - 0s 5ms/step - loss: 289.4012 - root_mean_squared_error: 17.0003 - val_loss: 280.6759 - val_root_mean_squared_error: 16.4530
# Epoch 126/250
# 39/39 [==============================] - 0s 5ms/step - loss: 290.1852 - root_mean_squared_error: 17.0313 - val_loss: 280.3103 - val_root_mean_squared_error: 16.4366
# Epoch 127/250
# 39/39 [==============================] - 0s 5ms/step - loss: 291.1008 - root_mean_squared_error: 17.0783 - val_loss: 282.4020 - val_root_mean_squared_error: 16.4780
# Epoch 128/250
# 39/39 [==============================] - 0s 5ms/step - loss: 287.4694 - root_mean_squared_error: 16.9635 - val_loss: 280.2488 - val_root_mean_squared_error: 16.4339
# Epoch 129/250
# 39/39 [==============================] - 0s 5ms/step - loss: 291.5127 - root_mean_squared_error: 17.0795 - val_loss: 279.7956 - val_root_mean_squared_error: 16.4227
# Epoch 130/250
# 39/39 [==============================] - 0s 5ms/step - loss: 290.0018 - root_mean_squared_error: 17.0107 - val_loss: 279.3811 - val_root_mean_squared_error: 16.4200
# Epoch 131/250
# 39/39 [==============================] - 0s 5ms/step - loss: 288.9864 - root_mean_squared_error: 16.9978 - val_loss: 279.6265 - val_root_mean_squared_error: 16.4119
# Epoch 132/250
# 39/39 [==============================] - 0s 5ms/step - loss: 289.6321 - root_mean_squared_error: 17.0063 - val_loss: 279.8020 - val_root_mean_squared_error: 16.4138
# Epoch 133/250
# 39/39 [==============================] - 0s 5ms/step - loss: 289.3727 - root_mean_squared_error: 17.0179 - val_loss: 279.3079 - val_root_mean_squared_error: 16.4171
# Epoch 134/250
# 39/39 [==============================] - 0s 5ms/step - loss: 288.1254 - root_mean_squared_error: 16.9755 - val_loss: 279.0689 - val_root_mean_squared_error: 16.3960
# Epoch 135/250
# 39/39 [==============================] - 0s 5ms/step - loss: 288.9329 - root_mean_squared_error: 16.9810 - val_loss: 278.4737 - val_root_mean_squared_error: 16.3831
# Epoch 136/250
# 39/39 [==============================] - 0s 5ms/step - loss: 287.6729 - root_mean_squared_error: 16.9850 - val_loss: 278.6343 - val_root_mean_squared_error: 16.3850
# Epoch 137/250
# 39/39 [==============================] - 0s 5ms/step - loss: 285.1271 - root_mean_squared_error: 16.8745 - val_loss: 279.6120 - val_root_mean_squared_error: 16.4021
# Epoch 138/250
# 39/39 [==============================] - 0s 5ms/step - loss: 286.2125 - root_mean_squared_error: 16.8869 - val_loss: 278.3338 - val_root_mean_squared_error: 16.4033
# Epoch 139/250
# 39/39 [==============================] - 0s 5ms/step - loss: 285.8466 - root_mean_squared_error: 16.8710 - val_loss: 277.4550 - val_root_mean_squared_error: 16.3594
# Epoch 140/250
# 39/39 [==============================] - 0s 5ms/step - loss: 285.8061 - root_mean_squared_error: 16.8924 - val_loss: 277.7164 - val_root_mean_squared_error: 16.3504
# Epoch 141/250
# 39/39 [==============================] - 0s 5ms/step - loss: 288.3821 - root_mean_squared_error: 16.9735 - val_loss: 277.2908 - val_root_mean_squared_error: 16.3480
# Epoch 142/250
# 39/39 [==============================] - 0s 5ms/step - loss: 286.6671 - root_mean_squared_error: 16.9235 - val_loss: 277.3295 - val_root_mean_squared_error: 16.3479
# Epoch 143/250
# 39/39 [==============================] - 0s 5ms/step - loss: 286.3616 - root_mean_squared_error: 16.9450 - val_loss: 277.2391 - val_root_mean_squared_error: 16.3435
# Epoch 144/250
# 39/39 [==============================] - 0s 5ms/step - loss: 285.5676 - root_mean_squared_error: 16.8970 - val_loss: 276.7700 - val_root_mean_squared_error: 16.3506
# Epoch 145/250
# 39/39 [==============================] - 0s 5ms/step - loss: 286.4423 - root_mean_squared_error: 16.9585 - val_loss: 276.4630 - val_root_mean_squared_error: 16.3321
# Epoch 146/250
# 39/39 [==============================] - 0s 5ms/step - loss: 286.7162 - root_mean_squared_error: 16.9393 - val_loss: 276.6098 - val_root_mean_squared_error: 16.3249
# Epoch 147/250
# 39/39 [==============================] - 0s 5ms/step - loss: 286.6245 - root_mean_squared_error: 16.9263 - val_loss: 277.3939 - val_root_mean_squared_error: 16.3337
# Epoch 148/250
# 39/39 [==============================] - 0s 5ms/step - loss: 286.4113 - root_mean_squared_error: 16.9000 - val_loss: 275.8206 - val_root_mean_squared_error: 16.3168
# Epoch 149/250
# 39/39 [==============================] - 0s 6ms/step - loss: 284.5010 - root_mean_squared_error: 16.8530 - val_loss: 275.7650 - val_root_mean_squared_error: 16.3025
# Epoch 150/250
# 39/39 [==============================] - 0s 5ms/step - loss: 283.6652 - root_mean_squared_error: 16.8305 - val_loss: 275.6230 - val_root_mean_squared_error: 16.2952
# Epoch 151/250
# 39/39 [==============================] - 0s 5ms/step - loss: 284.2277 - root_mean_squared_error: 16.8550 - val_loss: 275.5045 - val_root_mean_squared_error: 16.2950
# Epoch 152/250
# 39/39 [==============================] - 0s 5ms/step - loss: 284.2812 - root_mean_squared_error: 16.8603 - val_loss: 275.2526 - val_root_mean_squared_error: 16.2872
# Epoch 153/250
# 39/39 [==============================] - 0s 5ms/step - loss: 284.7300 - root_mean_squared_error: 16.8979 - val_loss: 275.0568 - val_root_mean_squared_error: 16.2868
# Epoch 154/250
# 39/39 [==============================] - 0s 5ms/step - loss: 284.5888 - root_mean_squared_error: 16.8846 - val_loss: 275.0122 - val_root_mean_squared_error: 16.2817
# Epoch 155/250
# 39/39 [==============================] - 0s 5ms/step - loss: 284.1514 - root_mean_squared_error: 16.8311 - val_loss: 275.5182 - val_root_mean_squared_error: 16.2910
# Epoch 156/250
# 39/39 [==============================] - 0s 5ms/step - loss: 284.0592 - root_mean_squared_error: 16.8556 - val_loss: 274.8214 - val_root_mean_squared_error: 16.2717
# Epoch 157/250
# 39/39 [==============================] - 0s 5ms/step - loss: 283.5030 - root_mean_squared_error: 16.8287 - val_loss: 275.0931 - val_root_mean_squared_error: 16.2721
# Epoch 158/250
# 39/39 [==============================] - 0s 5ms/step - loss: 283.3344 - root_mean_squared_error: 16.8352 - val_loss: 275.3767 - val_root_mean_squared_error: 16.2796
# Epoch 159/250
# 39/39 [==============================] - 0s 5ms/step - loss: 284.4153 - root_mean_squared_error: 16.8427 - val_loss: 275.0078 - val_root_mean_squared_error: 16.2725
# Epoch 160/250
# 39/39 [==============================] - 0s 5ms/step - loss: 282.0744 - root_mean_squared_error: 16.8113 - val_loss: 274.4190 - val_root_mean_squared_error: 16.2663
# Epoch 161/250
# 39/39 [==============================] - 0s 5ms/step - loss: 283.2395 - root_mean_squared_error: 16.8256 - val_loss: 274.1132 - val_root_mean_squared_error: 16.2440
# Epoch 162/250
# 39/39 [==============================] - 0s 5ms/step - loss: 283.4364 - root_mean_squared_error: 16.8618 - val_loss: 274.0407 - val_root_mean_squared_error: 16.2468
# Epoch 163/250
# 39/39 [==============================] - 0s 5ms/step - loss: 281.5251 - root_mean_squared_error: 16.7726 - val_loss: 274.1982 - val_root_mean_squared_error: 16.2471
# Epoch 164/250
# 39/39 [==============================] - 0s 5ms/step - loss: 283.5807 - root_mean_squared_error: 16.8160 - val_loss: 273.6138 - val_root_mean_squared_error: 16.2400
# Epoch 165/250
# 39/39 [==============================] - 0s 5ms/step - loss: 282.0945 - root_mean_squared_error: 16.8304 - val_loss: 273.4286 - val_root_mean_squared_error: 16.2282
# Epoch 166/250
# 39/39 [==============================] - 0s 5ms/step - loss: 282.9607 - root_mean_squared_error: 16.7946 - val_loss: 273.4729 - val_root_mean_squared_error: 16.2337
# Epoch 167/250
# 39/39 [==============================] - 0s 5ms/step - loss: 281.8716 - root_mean_squared_error: 16.7508 - val_loss: 272.8476 - val_root_mean_squared_error: 16.2183
# Epoch 168/250
# 39/39 [==============================] - 0s 5ms/step - loss: 283.6570 - root_mean_squared_error: 16.8473 - val_loss: 273.2951 - val_root_mean_squared_error: 16.2363
# Epoch 169/250
# 39/39 [==============================] - 0s 5ms/step - loss: 281.1570 - root_mean_squared_error: 16.7384 - val_loss: 273.4162 - val_root_mean_squared_error: 16.2223
# Epoch 170/250
# 39/39 [==============================] - 0s 5ms/step - loss: 282.3795 - root_mean_squared_error: 16.8060 - val_loss: 273.0705 - val_root_mean_squared_error: 16.2132
# Epoch 171/250
# 39/39 [==============================] - 0s 5ms/step - loss: 282.1019 - root_mean_squared_error: 16.8081 - val_loss: 272.5406 - val_root_mean_squared_error: 16.2030
# Epoch 172/250
# 39/39 [==============================] - 0s 5ms/step - loss: 281.3130 - root_mean_squared_error: 16.7901 - val_loss: 272.4167 - val_root_mean_squared_error: 16.2140
# Epoch 173/250
# 39/39 [==============================] - 0s 5ms/step - loss: 281.9883 - root_mean_squared_error: 16.7782 - val_loss: 272.9688 - val_root_mean_squared_error: 16.2057
# Epoch 174/250
# 39/39 [==============================] - 0s 5ms/step - loss: 282.2640 - root_mean_squared_error: 16.7966 - val_loss: 271.9038 - val_root_mean_squared_error: 16.1875
# Epoch 175/250
# 39/39 [==============================] - 0s 5ms/step - loss: 279.5793 - root_mean_squared_error: 16.6984 - val_loss: 271.7771 - val_root_mean_squared_error: 16.1918
# Epoch 176/250
# 39/39 [==============================] - 0s 5ms/step - loss: 280.7089 - root_mean_squared_error: 16.7147 - val_loss: 272.1241 - val_root_mean_squared_error: 16.1840
# Epoch 177/250
# 39/39 [==============================] - 0s 5ms/step - loss: 279.7333 - root_mean_squared_error: 16.7089 - val_loss: 271.9124 - val_root_mean_squared_error: 16.1835
# Epoch 178/250
# 39/39 [==============================] - 0s 5ms/step - loss: 279.4653 - root_mean_squared_error: 16.7173 - val_loss: 271.4902 - val_root_mean_squared_error: 16.1919
# Epoch 179/250
# 39/39 [==============================] - 0s 5ms/step - loss: 280.3900 - root_mean_squared_error: 16.7225 - val_loss: 271.2762 - val_root_mean_squared_error: 16.1662
# Epoch 180/250
# 39/39 [==============================] - 0s 5ms/step - loss: 278.5025 - root_mean_squared_error: 16.6948 - val_loss: 271.0057 - val_root_mean_squared_error: 16.1754
# Epoch 181/250
# 39/39 [==============================] - 0s 5ms/step - loss: 280.2966 - root_mean_squared_error: 16.7124 - val_loss: 270.9849 - val_root_mean_squared_error: 16.1706
# Epoch 182/250
# 39/39 [==============================] - 0s 5ms/step - loss: 279.3587 - root_mean_squared_error: 16.7166 - val_loss: 271.4858 - val_root_mean_squared_error: 16.1614
# Epoch 183/250
# 39/39 [==============================] - 0s 5ms/step - loss: 280.3299 - root_mean_squared_error: 16.7222 - val_loss: 271.0136 - val_root_mean_squared_error: 16.1492
# Epoch 184/250
# 39/39 [==============================] - 0s 5ms/step - loss: 279.6198 - root_mean_squared_error: 16.6664 - val_loss: 271.5735 - val_root_mean_squared_error: 16.1665
# Epoch 185/250
# 39/39 [==============================] - 0s 5ms/step - loss: 279.4790 - root_mean_squared_error: 16.7213 - val_loss: 270.7118 - val_root_mean_squared_error: 16.1506
# Epoch 186/250
# 39/39 [==============================] - 0s 5ms/step - loss: 278.8087 - root_mean_squared_error: 16.6892 - val_loss: 270.7321 - val_root_mean_squared_error: 16.1403
# Epoch 187/250
# 39/39 [==============================] - 0s 5ms/step - loss: 279.1435 - root_mean_squared_error: 16.6931 - val_loss: 270.0739 - val_root_mean_squared_error: 16.1433
# Epoch 188/250
# 39/39 [==============================] - 0s 5ms/step - loss: 279.4242 - root_mean_squared_error: 16.6948 - val_loss: 269.8269 - val_root_mean_squared_error: 16.1367
# Epoch 189/250
# 39/39 [==============================] - 0s 5ms/step - loss: 279.4617 - root_mean_squared_error: 16.7240 - val_loss: 270.0897 - val_root_mean_squared_error: 16.1267
# Epoch 190/250
# 39/39 [==============================] - 0s 5ms/step - loss: 279.1053 - root_mean_squared_error: 16.7163 - val_loss: 270.2002 - val_root_mean_squared_error: 16.1443
# Epoch 191/250
# 39/39 [==============================] - 0s 5ms/step - loss: 278.4789 - root_mean_squared_error: 16.6703 - val_loss: 270.1120 - val_root_mean_squared_error: 16.1201
# Epoch 192/250
# 39/39 [==============================] - 0s 5ms/step - loss: 278.1386 - root_mean_squared_error: 16.6702 - val_loss: 270.0324 - val_root_mean_squared_error: 16.1203
# Epoch 193/250
# 39/39 [==============================] - 0s 5ms/step - loss: 278.1841 - root_mean_squared_error: 16.6916 - val_loss: 269.4786 - val_root_mean_squared_error: 16.1235
# Epoch 194/250
# 39/39 [==============================] - 0s 5ms/step - loss: 279.0048 - root_mean_squared_error: 16.7209 - val_loss: 270.0896 - val_root_mean_squared_error: 16.1218
# Epoch 195/250
# 39/39 [==============================] - 0s 5ms/step - loss: 277.6423 - root_mean_squared_error: 16.6466 - val_loss: 269.5766 - val_root_mean_squared_error: 16.1082
# Epoch 196/250
# 39/39 [==============================] - 0s 5ms/step - loss: 278.6346 - root_mean_squared_error: 16.6750 - val_loss: 270.1614 - val_root_mean_squared_error: 16.1341
# Epoch 197/250
# 39/39 [==============================] - 0s 5ms/step - loss: 276.0313 - root_mean_squared_error: 16.6263 - val_loss: 269.0455 - val_root_mean_squared_error: 16.1010
# Epoch 198/250
# 39/39 [==============================] - 0s 5ms/step - loss: 277.3316 - root_mean_squared_error: 16.6537 - val_loss: 268.7288 - val_root_mean_squared_error: 16.1047
# Epoch 199/250
# 39/39 [==============================] - 0s 5ms/step - loss: 277.2200 - root_mean_squared_error: 16.6704 - val_loss: 268.5838 - val_root_mean_squared_error: 16.0905
# Epoch 200/250
# 39/39 [==============================] - 0s 5ms/step - loss: 279.0198 - root_mean_squared_error: 16.6669 - val_loss: 269.0622 - val_root_mean_squared_error: 16.0918
# Epoch 201/250
# 39/39 [==============================] - 0s 5ms/step - loss: 276.2715 - root_mean_squared_error: 16.6214 - val_loss: 270.4713 - val_root_mean_squared_error: 16.1155
# Epoch 202/250
# 39/39 [==============================] - 0s 5ms/step - loss: 276.8483 - root_mean_squared_error: 16.6202 - val_loss: 269.1872 - val_root_mean_squared_error: 16.0896
# Epoch 203/250
# 39/39 [==============================] - 0s 5ms/step - loss: 277.2159 - root_mean_squared_error: 16.6239 - val_loss: 268.5472 - val_root_mean_squared_error: 16.0792
# Epoch 204/250
# 39/39 [==============================] - 0s 6ms/step - loss: 277.5801 - root_mean_squared_error: 16.6614 - val_loss: 268.1639 - val_root_mean_squared_error: 16.0672
# Epoch 205/250
# 39/39 [==============================] - 0s 5ms/step - loss: 278.4328 - root_mean_squared_error: 16.7005 - val_loss: 267.7422 - val_root_mean_squared_error: 16.0710
# Epoch 206/250
# 39/39 [==============================] - 0s 5ms/step - loss: 275.3243 - root_mean_squared_error: 16.6013 - val_loss: 267.6210 - val_root_mean_squared_error: 16.0503
# Epoch 207/250
# 39/39 [==============================] - 0s 5ms/step - loss: 277.0401 - root_mean_squared_error: 16.6416 - val_loss: 267.7086 - val_root_mean_squared_error: 16.0717
# Epoch 208/250
# 39/39 [==============================] - 0s 5ms/step - loss: 275.2190 - root_mean_squared_error: 16.5552 - val_loss: 267.3943 - val_root_mean_squared_error: 16.0562
# Epoch 209/250
# 39/39 [==============================] - 0s 5ms/step - loss: 275.6878 - root_mean_squared_error: 16.5749 - val_loss: 267.8627 - val_root_mean_squared_error: 16.0572
# Epoch 210/250
# 39/39 [==============================] - 0s 5ms/step - loss: 275.0278 - root_mean_squared_error: 16.5302 - val_loss: 269.3638 - val_root_mean_squared_error: 16.0882
# Epoch 211/250
# 39/39 [==============================] - 0s 5ms/step - loss: 274.6504 - root_mean_squared_error: 16.5816 - val_loss: 266.8152 - val_root_mean_squared_error: 16.0425
# Epoch 212/250
# 39/39 [==============================] - 0s 5ms/step - loss: 276.3468 - root_mean_squared_error: 16.6271 - val_loss: 267.7304 - val_root_mean_squared_error: 16.0457
# Epoch 213/250
# 39/39 [==============================] - 0s 5ms/step - loss: 276.0324 - root_mean_squared_error: 16.6000 - val_loss: 267.1537 - val_root_mean_squared_error: 16.0414
# Epoch 214/250
# 39/39 [==============================] - 0s 5ms/step - loss: 275.8431 - root_mean_squared_error: 16.5988 - val_loss: 267.3141 - val_root_mean_squared_error: 16.0523
# Epoch 215/250
# 39/39 [==============================] - 0s 5ms/step - loss: 274.7723 - root_mean_squared_error: 16.5979 - val_loss: 266.9210 - val_root_mean_squared_error: 16.0405
# Epoch 216/250
# 39/39 [==============================] - 0s 5ms/step - loss: 276.5159 - root_mean_squared_error: 16.6306 - val_loss: 266.6237 - val_root_mean_squared_error: 16.0301
# Epoch 217/250
# 39/39 [==============================] - 0s 5ms/step - loss: 275.6317 - root_mean_squared_error: 16.5940 - val_loss: 266.8002 - val_root_mean_squared_error: 16.0323
# Epoch 218/250
# 39/39 [==============================] - 0s 5ms/step - loss: 275.3947 - root_mean_squared_error: 16.5729 - val_loss: 266.2213 - val_root_mean_squared_error: 16.0159
# Epoch 219/250
# 39/39 [==============================] - 0s 5ms/step - loss: 274.9440 - root_mean_squared_error: 16.5751 - val_loss: 266.0998 - val_root_mean_squared_error: 16.0284
# Epoch 220/250
# 39/39 [==============================] - 0s 5ms/step - loss: 275.1820 - root_mean_squared_error: 16.5656 - val_loss: 268.6028 - val_root_mean_squared_error: 16.0647
# Epoch 221/250
# 39/39 [==============================] - 0s 5ms/step - loss: 275.7322 - root_mean_squared_error: 16.6140 - val_loss: 265.8923 - val_root_mean_squared_error: 16.0224
# Epoch 222/250
# 39/39 [==============================] - 0s 5ms/step - loss: 275.3493 - root_mean_squared_error: 16.5945 - val_loss: 265.8139 - val_root_mean_squared_error: 16.0056
# Epoch 223/250
# 39/39 [==============================] - 0s 5ms/step - loss: 274.5410 - root_mean_squared_error: 16.5691 - val_loss: 266.1603 - val_root_mean_squared_error: 16.0112
# Epoch 224/250
# 39/39 [==============================] - 0s 6ms/step - loss: 274.8127 - root_mean_squared_error: 16.5981 - val_loss: 265.8493 - val_root_mean_squared_error: 16.0140
# Epoch 225/250
# 39/39 [==============================] - 0s 5ms/step - loss: 272.0132 - root_mean_squared_error: 16.4870 - val_loss: 265.6631 - val_root_mean_squared_error: 16.0070
# Epoch 226/250
# 39/39 [==============================] - 0s 5ms/step - loss: 275.0710 - root_mean_squared_error: 16.5732 - val_loss: 265.7142 - val_root_mean_squared_error: 15.9979
# Epoch 227/250
# 39/39 [==============================] - 0s 5ms/step - loss: 275.7124 - root_mean_squared_error: 16.5955 - val_loss: 265.3743 - val_root_mean_squared_error: 15.9908
# Epoch 228/250
# 39/39 [==============================] - 0s 5ms/step - loss: 274.3148 - root_mean_squared_error: 16.5470 - val_loss: 265.6308 - val_root_mean_squared_error: 15.9883
# Epoch 229/250
# 39/39 [==============================] - 0s 5ms/step - loss: 274.1805 - root_mean_squared_error: 16.5336 - val_loss: 265.0704 - val_root_mean_squared_error: 15.9934
# Epoch 230/250
# 39/39 [==============================] - 0s 5ms/step - loss: 274.7068 - root_mean_squared_error: 16.5741 - val_loss: 265.7468 - val_root_mean_squared_error: 15.9883
# Epoch 231/250
# 39/39 [==============================] - 0s 5ms/step - loss: 274.2931 - root_mean_squared_error: 16.5417 - val_loss: 265.4403 - val_root_mean_squared_error: 15.9860
# Epoch 232/250
# 39/39 [==============================] - 0s 5ms/step - loss: 274.1059 - root_mean_squared_error: 16.5386 - val_loss: 265.3682 - val_root_mean_squared_error: 15.9831
# Epoch 233/250
# 39/39 [==============================] - 0s 5ms/step - loss: 274.5350 - root_mean_squared_error: 16.5333 - val_loss: 265.0432 - val_root_mean_squared_error: 15.9921
# Epoch 234/250
# 39/39 [==============================] - 0s 5ms/step - loss: 274.1369 - root_mean_squared_error: 16.5395 - val_loss: 264.7539 - val_root_mean_squared_error: 15.9652
# Epoch 235/250
# 39/39 [==============================] - 0s 5ms/step - loss: 273.9433 - root_mean_squared_error: 16.5178 - val_loss: 264.6985 - val_root_mean_squared_error: 15.9914
# Epoch 236/250
# 39/39 [==============================] - 0s 5ms/step - loss: 273.9533 - root_mean_squared_error: 16.5343 - val_loss: 264.6829 - val_root_mean_squared_error: 15.9575
# Epoch 237/250
# 39/39 [==============================] - 0s 5ms/step - loss: 272.5933 - root_mean_squared_error: 16.5160 - val_loss: 264.0057 - val_root_mean_squared_error: 15.9606
# Epoch 238/250
# 39/39 [==============================] - 0s 5ms/step - loss: 272.2538 - root_mean_squared_error: 16.4835 - val_loss: 264.6915 - val_root_mean_squared_error: 15.9662
# Epoch 239/250
# 39/39 [==============================] - 0s 6ms/step - loss: 271.6763 - root_mean_squared_error: 16.4823 - val_loss: 264.1519 - val_root_mean_squared_error: 15.9633
# Epoch 240/250
# 39/39 [==============================] - 0s 5ms/step - loss: 273.0164 - root_mean_squared_error: 16.5208 - val_loss: 263.7624 - val_root_mean_squared_error: 15.9466
# Epoch 241/250
# 39/39 [==============================] - 0s 6ms/step - loss: 273.4107 - root_mean_squared_error: 16.5157 - val_loss: 263.8828 - val_root_mean_squared_error: 15.9483
# Epoch 242/250
# 39/39 [==============================] - 0s 5ms/step - loss: 270.1299 - root_mean_squared_error: 16.4203 - val_loss: 263.3694 - val_root_mean_squared_error: 15.9298
# Epoch 243/250
# 39/39 [==============================] - 0s 5ms/step - loss: 272.3852 - root_mean_squared_error: 16.5005 - val_loss: 263.6079 - val_root_mean_squared_error: 15.9399
# Epoch 244/250
# 39/39 [==============================] - 0s 5ms/step - loss: 272.5081 - root_mean_squared_error: 16.4949 - val_loss: 263.1497 - val_root_mean_squared_error: 15.9253
# Epoch 245/250
# 39/39 [==============================] - 0s 5ms/step - loss: 270.8431 - root_mean_squared_error: 16.4512 - val_loss: 263.0315 - val_root_mean_squared_error: 15.9360
# Epoch 246/250
# 39/39 [==============================] - 0s 5ms/step - loss: 273.7442 - root_mean_squared_error: 16.5435 - val_loss: 263.6386 - val_root_mean_squared_error: 15.9369
# Epoch 247/250
# 39/39 [==============================] - 0s 5ms/step - loss: 272.2881 - root_mean_squared_error: 16.4675 - val_loss: 264.1725 - val_root_mean_squared_error: 15.9439
# Epoch 248/250
# 39/39 [==============================] - 0s 5ms/step - loss: 271.6391 - root_mean_squared_error: 16.4832 - val_loss: 263.1148 - val_root_mean_squared_error: 15.9268
# Epoch 249/250
# 39/39 [==============================] - 0s 5ms/step - loss: 272.4277 - root_mean_squared_error: 16.4982 - val_loss: 263.1942 - val_root_mean_squared_error: 15.9257
# Epoch 250/250
# 39/39 [==============================] - 0s 5ms/step - loss: 270.8711 - root_mean_squared_error: 16.4632 - val_loss: 263.3366 - val_root_mean_squared_error: 15.9176

# %%
cnnturbofan.summary()
# Out:
# Model: "cnnturbofan"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 10, 14, 1)]       0
# _________________________________________________________________
# conv0 (Conv2D)               (None, 10, 14, 8)         456
# _________________________________________________________________
# activation (Activation)      (None, 10, 14, 8)         0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 5, 14, 8)          0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 5, 14, 14)         350
# _________________________________________________________________
# activation_1 (Activation)    (None, 5, 14, 14)         0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 2, 14, 14)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 392)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 392)               0
# _________________________________________________________________
# fully-connected (Dense)      (None, 1024)              402432
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# rul-neuron (Dense)           (None, 1)                 1025
# =================================================================
# Total params: 404,263
# Trainable params: 404,263
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(loss))

plt.figure(figsize=(10,6))
plt.grid(True) 
plt.plot(epochs, np.log10(loss), 'black',lw=0.9, label='Training Error')
plt.plot(epochs, np.log10(val_loss), 'orange',lw=0.9, label='Validation Error')
plt.ylabel("Log(Error)",fontsize=20)
plt.xlabel("# Epochs",fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('Training and validation Error', fontsize=20)
plt.legend(prop={"size":20})
  

plt.show()

# %%
# predictions es el vector de RUL estimado de los motores del test ordenados en orden descendente a partir de su rul verdadero (dataset FD001+FD003)
predictions = cnnturbofan.predict(f_maps_test_f1f3)

# %%
leng = range(len(predictions))


plt.figure(figsize=(8,8))
plt.grid(True) 
# predictions es el vector de RUL estimado de los motores del test set ordenados en orden descendente a partir de su rul verdadero (dataset FD001+FD003)
plt.plot(leng, predictions[::-1], 'bo',lw=0.9, label='predict RUL value')
# r_test_f1f3 es el vector de RUL verdadero ordenado en orden descendente del dataset FD001+FD003
plt.plot(leng, r_test_f1f3[::-1], 'ro',lw=0.9, label='true RUL value')
plt.fill_between([103,0],[120,120],facecolor='green',alpha=0.2)
plt.fill_between([150,103],[120,120],facecolor='yellow',alpha=0.2)
plt.fill_between([200,150],[120,120],facecolor='red',alpha=0.2)
plt.ylabel('RUL',fontsize=18)
plt.xlabel('Motor',fontsize=18)
plt.title('True and predict',fontsize=20)
plt.legend(prop={"size":15})
  

plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# Calculo de RUL y RUL por tramo early / mid y late

r_test_f1f3_early = r_test_f1f3[r_test_f1f3 <= 40]
predictions_early = predictions[:(len(r_test_f1f3_early))]
# _____________________________________

r_test_f1f3_late = r_test_f1f3[r_test_f1f3 > 80]
predictions_late = predictions[(len(predictions) - len(r_test_f1f3_late)):]
# _____________________________________

r_test_f1f3_mid = r_test_f1f3[(r_test_f1f3 > 40) & (r_test_f1f3 <= 80)]
predictions_mid = predictions[(len(r_test_f1f3_early)):(len(predictions) - len(r_test_f1f3_late))]

# ____________________________________

rmse = sqrt(mean_squared_error(predictions, r_test_f1f3))
rmse_early = sqrt(mean_squared_error(predictions_early,r_test_f1f3_early))
rmse_mid = sqrt(mean_squared_error(predictions_mid,r_test_f1f3_mid))
rmse_late = sqrt(mean_squared_error(predictions_late,r_test_f1f3_late))


print(rmse)
print(rmse_early)
print(rmse_mid)
print(rmse_late)
# Out:
# 18.359848556647936
# 17.287061389740924
# 26.530584625911686
# 13.681911799757897

# %% [markdown]
# ### FD002 + FD004

# %%
def cnnturbofan(input_shape):
   
    X_input = Input(input_shape)

    # CONV -> TANH aplicado a X
    X = Conv2D(8, (4, 14), strides = (1, 1),padding='same', name = 'conv0')(X_input)
    #X = BatchNormalization(axis = 3, name = 'bn0')(X)
    X = Activation('sigmoid')(X)

    #Layer 2

    X = AveragePooling2D(pool_size=(2,1))(X)
    #X = BatchNormalization(axis = 3, name = 'bn1')(X)

    #Layer 3

    X = Conv2D(14, (3, 1), strides = (1, 1), padding='same', name = 'conv1')(X)
    #X = BatchNormalization(axis = 3, name = 'bn2')(X)
    X = Activation('sigmoid')(X)

    #Layer 4

    X = AveragePooling2D(pool_size=(2,1))(X)
    #X = BatchNormalization(axis = 3, name = 'bn3')(X)


    # FLATTEN X ("desenrollamos el feature map anterior") + FULLYCONNECTED
    X = Flatten()(X)
    X = Dropout(0.5)(X)
    #X = BatchNormalization(name='bn5')(X)
    X = Dense(1024, activation='sigmoid', name='fully-connected')(X)
    X = Dropout(0.5)(X)
    #X = BatchNormalization(name='bn6')(X)
    X = Dense(1, name = 'rul-neuron')(X)

    # instancia modelo final
    model = Model(inputs = X_input, outputs = X, name='cnnturbofan')
    
  
    return model

# %%
cnnturbofan2 = cnnturbofan(((f_maps_24.shape[1]),(f_maps_24.shape[2]),(f_maps_24.shape[3])))

# %%
cnnturbofan2.compile(optimizer = OPTIM, loss = "mean_squared_error" , metrics = [root_mean_squared_error])

# %%
history2 = cnnturbofan2.fit(x = f_maps_24, y = y_24 ,batch_size=BATCH_SIZE_T, epochs = EPOCHS_MAX ,validation_split=0.1)
# Out:
# Epoch 1/250
# 98/98 [==============================] - 1s 6ms/step - loss: 3724.8511 - root_mean_squared_error: 59.5144 - val_loss: 1884.0479 - val_root_mean_squared_error: 43.4029
# Epoch 2/250
# 98/98 [==============================] - 0s 5ms/step - loss: 1652.0898 - root_mean_squared_error: 40.6011 - val_loss: 1575.9114 - val_root_mean_squared_error: 39.6615
# Epoch 3/250
# 98/98 [==============================] - 0s 5ms/step - loss: 1580.9921 - root_mean_squared_error: 39.7750 - val_loss: 1574.1857 - val_root_mean_squared_error: 39.6343
# Epoch 4/250
# 98/98 [==============================] - 0s 5ms/step - loss: 1579.3929 - root_mean_squared_error: 39.7217 - val_loss: 1574.1633 - val_root_mean_squared_error: 39.6345
# Epoch 5/250
# 98/98 [==============================] - 0s 5ms/step - loss: 1582.5454 - root_mean_squared_error: 39.7499 - val_loss: 1574.1479 - val_root_mean_squared_error: 39.6346
# Epoch 6/250
# 98/98 [==============================] - 0s 5ms/step - loss: 1579.5028 - root_mean_squared_error: 39.7616 - val_loss: 1574.0963 - val_root_mean_squared_error: 39.6331
# Epoch 7/250
# 98/98 [==============================] - 0s 5ms/step - loss: 1580.3969 - root_mean_squared_error: 39.7241 - val_loss: 1574.0728 - val_root_mean_squared_error: 39.6336
# Epoch 8/250
# 98/98 [==============================] - 0s 5ms/step - loss: 1580.2523 - root_mean_squared_error: 39.7412 - val_loss: 1574.0977 - val_root_mean_squared_error: 39.6346
# Epoch 9/250
# 98/98 [==============================] - 0s 5ms/step - loss: 1579.7986 - root_mean_squared_error: 39.7289 - val_loss: 1573.9694 - val_root_mean_squared_error: 39.6313
# Epoch 10/250
# 98/98 [==============================] - 0s 5ms/step - loss: 1578.9796 - root_mean_squared_error: 39.7537 - val_loss: 1574.1760 - val_root_mean_squared_error: 39.6367
# Epoch 11/250
# 98/98 [==============================] - 0s 5ms/step - loss: 1579.8661 - root_mean_squared_error: 39.7632 - val_loss: 1573.7469 - val_root_mean_squared_error: 39.6292
# Epoch 12/250
# 98/98 [==============================] - 0s 5ms/step - loss: 1578.6981 - root_mean_squared_error: 39.7243 - val_loss: 1573.5309 - val_root_mean_squared_error: 39.6270
# Epoch 13/250
# 98/98 [==============================] - 0s 5ms/step - loss: 1578.6274 - root_mean_squared_error: 39.7665 - val_loss: 1573.2095 - val_root_mean_squared_error: 39.6232
# Epoch 14/250
# 98/98 [==============================] - 0s 5ms/step - loss: 1579.6158 - root_mean_squared_error: 39.7824 - val_loss: 1572.6587 - val_root_mean_squared_error: 39.6132
# Epoch 15/250
# 98/98 [==============================] - 0s 5ms/step - loss: 1577.9359 - root_mean_squared_error: 39.7300 - val_loss: 1570.9722 - val_root_mean_squared_error: 39.5928
# Epoch 16/250
# 98/98 [==============================] - 0s 5ms/step - loss: 1575.0375 - root_mean_squared_error: 39.7065 - val_loss: 1568.4965 - val_root_mean_squared_error: 39.5604
# Epoch 17/250
# 98/98 [==============================] - 0s 5ms/step - loss: 1575.2502 - root_mean_squared_error: 39.6511 - val_loss: 1563.0066 - val_root_mean_squared_error: 39.4954
# Epoch 18/250
# 98/98 [==============================] - 0s 5ms/step - loss: 1564.6371 - root_mean_squared_error: 39.5320 - val_loss: 1541.0226 - val_root_mean_squared_error: 39.2114
# Epoch 19/250
# 98/98 [==============================] - 0s 5ms/step - loss: 1505.8344 - root_mean_squared_error: 38.8131 - val_loss: 1391.1299 - val_root_mean_squared_error: 37.2674
# Epoch 20/250
# 98/98 [==============================] - 0s 5ms/step - loss: 1292.5266 - root_mean_squared_error: 35.9177 - val_loss: 1019.2623 - val_root_mean_squared_error: 31.9248
# Epoch 21/250
# 98/98 [==============================] - 0s 5ms/step - loss: 996.4504 - root_mean_squared_error: 31.5304 - val_loss: 798.8995 - val_root_mean_squared_error: 28.2677
# Epoch 22/250
# 98/98 [==============================] - 0s 5ms/step - loss: 859.5261 - root_mean_squared_error: 29.3458 - val_loss: 729.8391 - val_root_mean_squared_error: 27.0194
# Epoch 23/250
# 98/98 [==============================] - 0s 5ms/step - loss: 798.3795 - root_mean_squared_error: 28.2210 - val_loss: 698.6454 - val_root_mean_squared_error: 26.4359
# Epoch 24/250
# 98/98 [==============================] - 1s 5ms/step - loss: 765.2215 - root_mean_squared_error: 27.6975 - val_loss: 679.0082 - val_root_mean_squared_error: 26.0635
# Epoch 25/250
# 98/98 [==============================] - 0s 5ms/step - loss: 748.6293 - root_mean_squared_error: 27.3822 - val_loss: 670.1257 - val_root_mean_squared_error: 25.8817
# Epoch 26/250
# 98/98 [==============================] - 0s 5ms/step - loss: 732.8586 - root_mean_squared_error: 27.0730 - val_loss: 656.3363 - val_root_mean_squared_error: 25.6275
# Epoch 27/250
# 98/98 [==============================] - 0s 5ms/step - loss: 718.1005 - root_mean_squared_error: 26.8035 - val_loss: 654.7838 - val_root_mean_squared_error: 25.5813
# Epoch 28/250
# 98/98 [==============================] - 0s 5ms/step - loss: 713.2539 - root_mean_squared_error: 26.6946 - val_loss: 647.8309 - val_root_mean_squared_error: 25.4501
# Epoch 29/250
# 98/98 [==============================] - 0s 5ms/step - loss: 702.7283 - root_mean_squared_error: 26.4901 - val_loss: 645.6577 - val_root_mean_squared_error: 25.4002
# Epoch 30/250
# 98/98 [==============================] - 0s 5ms/step - loss: 697.1404 - root_mean_squared_error: 26.3749 - val_loss: 637.3771 - val_root_mean_squared_error: 25.2551
# Epoch 31/250
# 98/98 [==============================] - 0s 5ms/step - loss: 695.2295 - root_mean_squared_error: 26.3923 - val_loss: 634.0750 - val_root_mean_squared_error: 25.1897
# Epoch 32/250
# 98/98 [==============================] - 0s 5ms/step - loss: 686.7856 - root_mean_squared_error: 26.2085 - val_loss: 631.8417 - val_root_mean_squared_error: 25.1443
# Epoch 33/250
# 98/98 [==============================] - 0s 5ms/step - loss: 683.1053 - root_mean_squared_error: 26.1354 - val_loss: 628.4686 - val_root_mean_squared_error: 25.0754
# Epoch 34/250
# 98/98 [==============================] - 0s 5ms/step - loss: 682.0964 - root_mean_squared_error: 26.0745 - val_loss: 626.2056 - val_root_mean_squared_error: 25.0329
# Epoch 35/250
# 98/98 [==============================] - 0s 5ms/step - loss: 677.2545 - root_mean_squared_error: 25.9936 - val_loss: 628.6816 - val_root_mean_squared_error: 25.0642
# Epoch 36/250
# 98/98 [==============================] - 0s 5ms/step - loss: 677.8038 - root_mean_squared_error: 25.9892 - val_loss: 623.5319 - val_root_mean_squared_error: 24.9729
# Epoch 37/250
# 98/98 [==============================] - 0s 5ms/step - loss: 673.9810 - root_mean_squared_error: 25.9744 - val_loss: 621.7607 - val_root_mean_squared_error: 24.9326
# Epoch 38/250
# 98/98 [==============================] - 0s 5ms/step - loss: 670.2250 - root_mean_squared_error: 25.8748 - val_loss: 619.2667 - val_root_mean_squared_error: 24.8848
# Epoch 39/250
# 98/98 [==============================] - 0s 5ms/step - loss: 667.4553 - root_mean_squared_error: 25.8074 - val_loss: 620.4914 - val_root_mean_squared_error: 24.8999
# Epoch 40/250
# 98/98 [==============================] - 0s 5ms/step - loss: 664.5693 - root_mean_squared_error: 25.7876 - val_loss: 615.3111 - val_root_mean_squared_error: 24.8136
# Epoch 41/250
# 98/98 [==============================] - 0s 5ms/step - loss: 662.5193 - root_mean_squared_error: 25.7149 - val_loss: 613.4026 - val_root_mean_squared_error: 24.7684
# Epoch 42/250
# 98/98 [==============================] - 0s 5ms/step - loss: 658.9265 - root_mean_squared_error: 25.6949 - val_loss: 611.0579 - val_root_mean_squared_error: 24.7261
# Epoch 43/250
# 98/98 [==============================] - 0s 5ms/step - loss: 656.5316 - root_mean_squared_error: 25.5537 - val_loss: 609.9427 - val_root_mean_squared_error: 24.7036
# Epoch 44/250
# 98/98 [==============================] - 0s 5ms/step - loss: 654.7640 - root_mean_squared_error: 25.5888 - val_loss: 607.5457 - val_root_mean_squared_error: 24.6544
# Epoch 45/250
# 98/98 [==============================] - 0s 5ms/step - loss: 651.1604 - root_mean_squared_error: 25.5368 - val_loss: 607.4496 - val_root_mean_squared_error: 24.6414
# Epoch 46/250
# 98/98 [==============================] - 0s 5ms/step - loss: 649.3938 - root_mean_squared_error: 25.5120 - val_loss: 604.0233 - val_root_mean_squared_error: 24.5809
# Epoch 47/250
# 98/98 [==============================] - 0s 5ms/step - loss: 647.2759 - root_mean_squared_error: 25.4623 - val_loss: 613.1282 - val_root_mean_squared_error: 24.7236
# Epoch 48/250
# 98/98 [==============================] - 0s 5ms/step - loss: 647.0828 - root_mean_squared_error: 25.4494 - val_loss: 602.3100 - val_root_mean_squared_error: 24.5324
# Epoch 49/250
# 98/98 [==============================] - 0s 5ms/step - loss: 643.9308 - root_mean_squared_error: 25.3568 - val_loss: 607.3118 - val_root_mean_squared_error: 24.6089
# Epoch 50/250
# 98/98 [==============================] - 0s 5ms/step - loss: 643.1927 - root_mean_squared_error: 25.3628 - val_loss: 597.1856 - val_root_mean_squared_error: 24.4296
# Epoch 51/250
# 98/98 [==============================] - 0s 5ms/step - loss: 640.9121 - root_mean_squared_error: 25.3259 - val_loss: 595.0006 - val_root_mean_squared_error: 24.3852
# Epoch 52/250
# 98/98 [==============================] - 0s 5ms/step - loss: 635.0529 - root_mean_squared_error: 25.2073 - val_loss: 594.7728 - val_root_mean_squared_error: 24.3734
# Epoch 53/250
# 98/98 [==============================] - 0s 5ms/step - loss: 633.9949 - root_mean_squared_error: 25.1388 - val_loss: 593.5510 - val_root_mean_squared_error: 24.3459
# Epoch 54/250
# 98/98 [==============================] - 0s 5ms/step - loss: 631.6080 - root_mean_squared_error: 25.1209 - val_loss: 590.4162 - val_root_mean_squared_error: 24.2876
# Epoch 55/250
# 98/98 [==============================] - 0s 5ms/step - loss: 629.7845 - root_mean_squared_error: 25.0741 - val_loss: 591.2745 - val_root_mean_squared_error: 24.2910
# Epoch 56/250
# 98/98 [==============================] - 0s 5ms/step - loss: 628.0907 - root_mean_squared_error: 25.0799 - val_loss: 589.3629 - val_root_mean_squared_error: 24.2526
# Epoch 57/250
# 98/98 [==============================] - 0s 5ms/step - loss: 625.8340 - root_mean_squared_error: 25.0034 - val_loss: 584.5464 - val_root_mean_squared_error: 24.1711
# Epoch 58/250
# 98/98 [==============================] - 0s 5ms/step - loss: 624.9087 - root_mean_squared_error: 24.9442 - val_loss: 585.4519 - val_root_mean_squared_error: 24.1787
# Epoch 59/250
# 98/98 [==============================] - 0s 5ms/step - loss: 624.7146 - root_mean_squared_error: 25.0108 - val_loss: 583.7276 - val_root_mean_squared_error: 24.1415
# Epoch 60/250
# 98/98 [==============================] - 0s 5ms/step - loss: 623.2477 - root_mean_squared_error: 24.9307 - val_loss: 583.3277 - val_root_mean_squared_error: 24.1298
# Epoch 61/250
# 98/98 [==============================] - 0s 5ms/step - loss: 621.3364 - root_mean_squared_error: 24.9449 - val_loss: 583.4622 - val_root_mean_squared_error: 24.1275
# Epoch 62/250
# 98/98 [==============================] - 0s 5ms/step - loss: 621.5056 - root_mean_squared_error: 24.9197 - val_loss: 577.3889 - val_root_mean_squared_error: 24.0293
# Epoch 63/250
# 98/98 [==============================] - 0s 5ms/step - loss: 619.8742 - root_mean_squared_error: 24.8562 - val_loss: 577.1730 - val_root_mean_squared_error: 24.0099
# Epoch 64/250
# 98/98 [==============================] - 0s 5ms/step - loss: 616.7673 - root_mean_squared_error: 24.7948 - val_loss: 576.6315 - val_root_mean_squared_error: 24.0019
# Epoch 65/250
# 98/98 [==============================] - 0s 5ms/step - loss: 616.6091 - root_mean_squared_error: 24.8259 - val_loss: 574.1387 - val_root_mean_squared_error: 23.9625
# Epoch 66/250
# 98/98 [==============================] - 0s 5ms/step - loss: 615.9963 - root_mean_squared_error: 24.8463 - val_loss: 579.7472 - val_root_mean_squared_error: 24.0407
# Epoch 67/250
# 98/98 [==============================] - 0s 5ms/step - loss: 613.7456 - root_mean_squared_error: 24.7686 - val_loss: 574.8920 - val_root_mean_squared_error: 23.9514
# Epoch 68/250
# 98/98 [==============================] - 0s 5ms/step - loss: 612.0014 - root_mean_squared_error: 24.7462 - val_loss: 571.5389 - val_root_mean_squared_error: 23.8910
# Epoch 69/250
# 98/98 [==============================] - 0s 5ms/step - loss: 613.5258 - root_mean_squared_error: 24.7619 - val_loss: 572.6566 - val_root_mean_squared_error: 23.9074
# Epoch 70/250
# 98/98 [==============================] - 0s 5ms/step - loss: 610.9949 - root_mean_squared_error: 24.7427 - val_loss: 570.1652 - val_root_mean_squared_error: 23.8584
# Epoch 71/250
# 98/98 [==============================] - 0s 5ms/step - loss: 607.7626 - root_mean_squared_error: 24.6327 - val_loss: 570.9279 - val_root_mean_squared_error: 23.8619
# Epoch 72/250
# 98/98 [==============================] - 0s 5ms/step - loss: 608.3541 - root_mean_squared_error: 24.6996 - val_loss: 566.2867 - val_root_mean_squared_error: 23.7853
# Epoch 73/250
# 98/98 [==============================] - 0s 5ms/step - loss: 605.2596 - root_mean_squared_error: 24.5920 - val_loss: 568.4015 - val_root_mean_squared_error: 23.8125
# Epoch 74/250
# 98/98 [==============================] - 0s 5ms/step - loss: 605.9413 - root_mean_squared_error: 24.5557 - val_loss: 563.5516 - val_root_mean_squared_error: 23.7304
# Epoch 75/250
# 98/98 [==============================] - 1s 5ms/step - loss: 603.3842 - root_mean_squared_error: 24.5622 - val_loss: 564.8175 - val_root_mean_squared_error: 23.7409
# Epoch 76/250
# 98/98 [==============================] - 0s 5ms/step - loss: 600.6392 - root_mean_squared_error: 24.4504 - val_loss: 562.8408 - val_root_mean_squared_error: 23.7061
# Epoch 77/250
# 98/98 [==============================] - 1s 5ms/step - loss: 602.6927 - root_mean_squared_error: 24.5558 - val_loss: 562.6406 - val_root_mean_squared_error: 23.7028
# Epoch 78/250
# 98/98 [==============================] - 0s 5ms/step - loss: 600.7582 - root_mean_squared_error: 24.4946 - val_loss: 558.8092 - val_root_mean_squared_error: 23.6296
# Epoch 79/250
# 98/98 [==============================] - 1s 5ms/step - loss: 598.9791 - root_mean_squared_error: 24.4472 - val_loss: 560.8350 - val_root_mean_squared_error: 23.6568
# Epoch 80/250
# 98/98 [==============================] - 1s 5ms/step - loss: 596.0917 - root_mean_squared_error: 24.3978 - val_loss: 558.1072 - val_root_mean_squared_error: 23.6072
# Epoch 81/250
# 98/98 [==============================] - 1s 5ms/step - loss: 597.4641 - root_mean_squared_error: 24.4531 - val_loss: 562.2567 - val_root_mean_squared_error: 23.6714
# Epoch 82/250
# 98/98 [==============================] - 0s 5ms/step - loss: 596.3067 - root_mean_squared_error: 24.4281 - val_loss: 557.4410 - val_root_mean_squared_error: 23.5910
# Epoch 83/250
# 98/98 [==============================] - 1s 5ms/step - loss: 595.6116 - root_mean_squared_error: 24.4079 - val_loss: 558.8099 - val_root_mean_squared_error: 23.6012
# Epoch 84/250
# 98/98 [==============================] - 0s 5ms/step - loss: 594.5072 - root_mean_squared_error: 24.3661 - val_loss: 552.9572 - val_root_mean_squared_error: 23.4981
# Epoch 85/250
# 98/98 [==============================] - 0s 5ms/step - loss: 592.4413 - root_mean_squared_error: 24.3091 - val_loss: 552.8102 - val_root_mean_squared_error: 23.4920
# Epoch 86/250
# 98/98 [==============================] - 0s 5ms/step - loss: 594.2928 - root_mean_squared_error: 24.3453 - val_loss: 551.9385 - val_root_mean_squared_error: 23.4783
# Epoch 87/250
# 98/98 [==============================] - 0s 5ms/step - loss: 591.8779 - root_mean_squared_error: 24.3266 - val_loss: 552.7729 - val_root_mean_squared_error: 23.4843
# Epoch 88/250
# 98/98 [==============================] - 0s 5ms/step - loss: 589.3813 - root_mean_squared_error: 24.2587 - val_loss: 549.4750 - val_root_mean_squared_error: 23.4310
# Epoch 89/250
# 98/98 [==============================] - 0s 5ms/step - loss: 589.4507 - root_mean_squared_error: 24.2731 - val_loss: 549.8189 - val_root_mean_squared_error: 23.4208
# Epoch 90/250
# 98/98 [==============================] - 0s 5ms/step - loss: 586.8689 - root_mean_squared_error: 24.2231 - val_loss: 551.6548 - val_root_mean_squared_error: 23.4480
# Epoch 91/250
# 98/98 [==============================] - 1s 5ms/step - loss: 586.3604 - root_mean_squared_error: 24.2383 - val_loss: 548.4035 - val_root_mean_squared_error: 23.3914
# Epoch 92/250
# 98/98 [==============================] - 0s 5ms/step - loss: 585.9427 - root_mean_squared_error: 24.2087 - val_loss: 547.0002 - val_root_mean_squared_error: 23.3628
# Epoch 93/250
# 98/98 [==============================] - 0s 5ms/step - loss: 584.8183 - root_mean_squared_error: 24.1245 - val_loss: 544.2931 - val_root_mean_squared_error: 23.3122
# Epoch 94/250
# 98/98 [==============================] - 0s 5ms/step - loss: 582.6043 - root_mean_squared_error: 24.1266 - val_loss: 542.7766 - val_root_mean_squared_error: 23.2858
# Epoch 95/250
# 98/98 [==============================] - 1s 5ms/step - loss: 581.5675 - root_mean_squared_error: 24.1060 - val_loss: 542.5557 - val_root_mean_squared_error: 23.2768
# Epoch 96/250
# 98/98 [==============================] - 0s 5ms/step - loss: 579.3088 - root_mean_squared_error: 24.0665 - val_loss: 543.4709 - val_root_mean_squared_error: 23.2807
# Epoch 97/250
# 98/98 [==============================] - 1s 5ms/step - loss: 580.8586 - root_mean_squared_error: 24.0868 - val_loss: 548.1367 - val_root_mean_squared_error: 23.3664
# Epoch 98/250
# 98/98 [==============================] - 0s 5ms/step - loss: 579.5205 - root_mean_squared_error: 24.0586 - val_loss: 541.1367 - val_root_mean_squared_error: 23.2343
# Epoch 99/250
# 98/98 [==============================] - 1s 5ms/step - loss: 577.5453 - root_mean_squared_error: 24.0089 - val_loss: 540.9578 - val_root_mean_squared_error: 23.2237
# Epoch 100/250
# 98/98 [==============================] - 0s 5ms/step - loss: 581.3950 - root_mean_squared_error: 24.1123 - val_loss: 539.4448 - val_root_mean_squared_error: 23.2014
# Epoch 101/250
# 98/98 [==============================] - 1s 5ms/step - loss: 576.3804 - root_mean_squared_error: 23.9788 - val_loss: 535.5899 - val_root_mean_squared_error: 23.1349
# Epoch 102/250
# 98/98 [==============================] - 0s 5ms/step - loss: 574.8179 - root_mean_squared_error: 24.0045 - val_loss: 533.6439 - val_root_mean_squared_error: 23.0869
# Epoch 103/250
# 98/98 [==============================] - 0s 5ms/step - loss: 572.7834 - root_mean_squared_error: 23.9093 - val_loss: 532.9442 - val_root_mean_squared_error: 23.0748
# Epoch 104/250
# 98/98 [==============================] - 0s 5ms/step - loss: 573.5921 - root_mean_squared_error: 23.9075 - val_loss: 532.3502 - val_root_mean_squared_error: 23.0647
# Epoch 105/250
# 98/98 [==============================] - 0s 5ms/step - loss: 570.5243 - root_mean_squared_error: 23.8761 - val_loss: 533.0515 - val_root_mean_squared_error: 23.0671
# Epoch 106/250
# 98/98 [==============================] - 0s 5ms/step - loss: 570.6304 - root_mean_squared_error: 23.9043 - val_loss: 534.7310 - val_root_mean_squared_error: 23.0901
# Epoch 107/250
# 98/98 [==============================] - 0s 5ms/step - loss: 570.5771 - root_mean_squared_error: 23.9016 - val_loss: 533.5330 - val_root_mean_squared_error: 23.0621
# Epoch 108/250
# 98/98 [==============================] - 0s 5ms/step - loss: 569.5147 - root_mean_squared_error: 23.8071 - val_loss: 528.3459 - val_root_mean_squared_error: 22.9691
# Epoch 109/250
# 98/98 [==============================] - 0s 5ms/step - loss: 569.0411 - root_mean_squared_error: 23.8201 - val_loss: 526.9984 - val_root_mean_squared_error: 22.9464
# Epoch 110/250
# 98/98 [==============================] - 0s 5ms/step - loss: 566.4720 - root_mean_squared_error: 23.7975 - val_loss: 528.3152 - val_root_mean_squared_error: 22.9614
# Epoch 111/250
# 98/98 [==============================] - 0s 5ms/step - loss: 565.2988 - root_mean_squared_error: 23.7616 - val_loss: 527.1528 - val_root_mean_squared_error: 22.9277
# Epoch 112/250
# 98/98 [==============================] - 0s 5ms/step - loss: 568.2122 - root_mean_squared_error: 23.8558 - val_loss: 524.8175 - val_root_mean_squared_error: 22.8862
# Epoch 113/250
# 98/98 [==============================] - 0s 5ms/step - loss: 563.1673 - root_mean_squared_error: 23.7530 - val_loss: 522.9986 - val_root_mean_squared_error: 22.8563
# Epoch 114/250
# 98/98 [==============================] - 0s 5ms/step - loss: 561.0350 - root_mean_squared_error: 23.6640 - val_loss: 521.2404 - val_root_mean_squared_error: 22.8272
# Epoch 115/250
# 98/98 [==============================] - 1s 5ms/step - loss: 561.5714 - root_mean_squared_error: 23.7262 - val_loss: 528.3833 - val_root_mean_squared_error: 22.9283
# Epoch 116/250
# 98/98 [==============================] - 0s 5ms/step - loss: 563.1431 - root_mean_squared_error: 23.7117 - val_loss: 519.6277 - val_root_mean_squared_error: 22.7757
# Epoch 117/250
# 98/98 [==============================] - 1s 6ms/step - loss: 561.3101 - root_mean_squared_error: 23.7044 - val_loss: 520.3703 - val_root_mean_squared_error: 22.7844
# Epoch 118/250
# 98/98 [==============================] - 1s 5ms/step - loss: 558.9839 - root_mean_squared_error: 23.5930 - val_loss: 519.8867 - val_root_mean_squared_error: 22.7710
# Epoch 119/250
# 98/98 [==============================] - 1s 5ms/step - loss: 557.3598 - root_mean_squared_error: 23.5704 - val_loss: 517.5775 - val_root_mean_squared_error: 22.7231
# Epoch 120/250
# 98/98 [==============================] - 1s 5ms/step - loss: 557.4950 - root_mean_squared_error: 23.5814 - val_loss: 520.1558 - val_root_mean_squared_error: 22.7645
# Epoch 121/250
# 98/98 [==============================] - 1s 5ms/step - loss: 557.2153 - root_mean_squared_error: 23.5733 - val_loss: 516.7369 - val_root_mean_squared_error: 22.6970
# Epoch 122/250
# 98/98 [==============================] - 1s 5ms/step - loss: 555.9730 - root_mean_squared_error: 23.5210 - val_loss: 516.7393 - val_root_mean_squared_error: 22.6946
# Epoch 123/250
# 98/98 [==============================] - 1s 6ms/step - loss: 554.7678 - root_mean_squared_error: 23.5400 - val_loss: 512.6111 - val_root_mean_squared_error: 22.6234
# Epoch 124/250
# 98/98 [==============================] - 1s 5ms/step - loss: 554.4904 - root_mean_squared_error: 23.5226 - val_loss: 513.5526 - val_root_mean_squared_error: 22.6363
# Epoch 125/250
# 98/98 [==============================] - 1s 5ms/step - loss: 552.3207 - root_mean_squared_error: 23.4931 - val_loss: 513.7949 - val_root_mean_squared_error: 22.6310
# Epoch 126/250
# 98/98 [==============================] - 1s 5ms/step - loss: 551.4095 - root_mean_squared_error: 23.4961 - val_loss: 508.9905 - val_root_mean_squared_error: 22.5406
# Epoch 127/250
# 98/98 [==============================] - 1s 6ms/step - loss: 550.7673 - root_mean_squared_error: 23.4479 - val_loss: 507.3912 - val_root_mean_squared_error: 22.5065
# Epoch 128/250
# 98/98 [==============================] - 1s 5ms/step - loss: 548.8649 - root_mean_squared_error: 23.4043 - val_loss: 505.9880 - val_root_mean_squared_error: 22.4716
# Epoch 129/250
# 98/98 [==============================] - 1s 5ms/step - loss: 543.8105 - root_mean_squared_error: 23.3010 - val_loss: 509.4636 - val_root_mean_squared_error: 22.5145
# Epoch 130/250
# 98/98 [==============================] - 1s 5ms/step - loss: 542.4655 - root_mean_squared_error: 23.3047 - val_loss: 498.9055 - val_root_mean_squared_error: 22.3157
# Epoch 131/250
# 98/98 [==============================] - 1s 5ms/step - loss: 540.4354 - root_mean_squared_error: 23.2542 - val_loss: 495.4073 - val_root_mean_squared_error: 22.2480
# Epoch 132/250
# 98/98 [==============================] - 1s 5ms/step - loss: 536.3907 - root_mean_squared_error: 23.1742 - val_loss: 492.3430 - val_root_mean_squared_error: 22.1694
# Epoch 133/250
# 98/98 [==============================] - 1s 5ms/step - loss: 533.3937 - root_mean_squared_error: 23.0970 - val_loss: 490.2664 - val_root_mean_squared_error: 22.1194
# Epoch 134/250
# 98/98 [==============================] - 1s 5ms/step - loss: 532.0993 - root_mean_squared_error: 23.0320 - val_loss: 487.2163 - val_root_mean_squared_error: 22.0472
# Epoch 135/250
# 98/98 [==============================] - 1s 5ms/step - loss: 531.3568 - root_mean_squared_error: 23.0508 - val_loss: 501.7460 - val_root_mean_squared_error: 22.3019
# Epoch 136/250
# 98/98 [==============================] - 1s 5ms/step - loss: 527.7229 - root_mean_squared_error: 22.9350 - val_loss: 483.2968 - val_root_mean_squared_error: 21.9578
# Epoch 137/250
# 98/98 [==============================] - 0s 5ms/step - loss: 526.2510 - root_mean_squared_error: 22.9368 - val_loss: 481.2881 - val_root_mean_squared_error: 21.9109
# Epoch 138/250
# 98/98 [==============================] - 0s 5ms/step - loss: 524.5663 - root_mean_squared_error: 22.9125 - val_loss: 493.5618 - val_root_mean_squared_error: 22.1339
# Epoch 139/250
# 98/98 [==============================] - 0s 5ms/step - loss: 522.9389 - root_mean_squared_error: 22.8481 - val_loss: 477.4030 - val_root_mean_squared_error: 21.8168
# Epoch 140/250
# 98/98 [==============================] - 1s 5ms/step - loss: 521.3285 - root_mean_squared_error: 22.7698 - val_loss: 476.6344 - val_root_mean_squared_error: 21.7911
# Epoch 141/250
# 98/98 [==============================] - 0s 5ms/step - loss: 518.5333 - root_mean_squared_error: 22.7443 - val_loss: 472.9555 - val_root_mean_squared_error: 21.7218
# Epoch 142/250
# 98/98 [==============================] - 1s 5ms/step - loss: 519.4792 - root_mean_squared_error: 22.8240 - val_loss: 476.9078 - val_root_mean_squared_error: 21.7941
# Epoch 143/250
# 98/98 [==============================] - 0s 5ms/step - loss: 516.7213 - root_mean_squared_error: 22.7298 - val_loss: 471.0576 - val_root_mean_squared_error: 21.6638
# Epoch 144/250
# 98/98 [==============================] - 1s 5ms/step - loss: 515.6060 - root_mean_squared_error: 22.6958 - val_loss: 470.9240 - val_root_mean_squared_error: 21.6605
# Epoch 145/250
# 98/98 [==============================] - 0s 5ms/step - loss: 514.4987 - root_mean_squared_error: 22.6654 - val_loss: 470.0576 - val_root_mean_squared_error: 21.6356
# Epoch 146/250
# 98/98 [==============================] - 1s 5ms/step - loss: 510.5640 - root_mean_squared_error: 22.5726 - val_loss: 465.7472 - val_root_mean_squared_error: 21.5496
# Epoch 147/250
# 98/98 [==============================] - 0s 5ms/step - loss: 509.6120 - root_mean_squared_error: 22.5773 - val_loss: 464.8228 - val_root_mean_squared_error: 21.5266
# Epoch 148/250
# 98/98 [==============================] - 1s 5ms/step - loss: 507.5479 - root_mean_squared_error: 22.5110 - val_loss: 465.2066 - val_root_mean_squared_error: 21.5146
# Epoch 149/250
# 98/98 [==============================] - 1s 5ms/step - loss: 507.7234 - root_mean_squared_error: 22.5212 - val_loss: 460.3784 - val_root_mean_squared_error: 21.4304
# Epoch 150/250
# 98/98 [==============================] - 1s 5ms/step - loss: 510.3695 - root_mean_squared_error: 22.6086 - val_loss: 459.2698 - val_root_mean_squared_error: 21.3976
# Epoch 151/250
# 98/98 [==============================] - 0s 5ms/step - loss: 504.4490 - root_mean_squared_error: 22.4382 - val_loss: 455.7788 - val_root_mean_squared_error: 21.3328
# Epoch 152/250
# 98/98 [==============================] - 1s 5ms/step - loss: 503.3483 - root_mean_squared_error: 22.4058 - val_loss: 457.6902 - val_root_mean_squared_error: 21.3504
# Epoch 153/250
# 98/98 [==============================] - 0s 5ms/step - loss: 503.7680 - root_mean_squared_error: 22.4659 - val_loss: 460.1237 - val_root_mean_squared_error: 21.3896
# Epoch 154/250
# 98/98 [==============================] - 1s 5ms/step - loss: 501.8763 - root_mean_squared_error: 22.3749 - val_loss: 453.2131 - val_root_mean_squared_error: 21.2516
# Epoch 155/250
# 98/98 [==============================] - 1s 5ms/step - loss: 499.5888 - root_mean_squared_error: 22.3084 - val_loss: 451.5556 - val_root_mean_squared_error: 21.2148
# Epoch 156/250
# 98/98 [==============================] - 1s 5ms/step - loss: 498.5295 - root_mean_squared_error: 22.2678 - val_loss: 448.3593 - val_root_mean_squared_error: 21.1490
# Epoch 157/250
# 98/98 [==============================] - 1s 5ms/step - loss: 498.0951 - root_mean_squared_error: 22.3314 - val_loss: 447.3160 - val_root_mean_squared_error: 21.1280
# Epoch 158/250
# 98/98 [==============================] - 1s 5ms/step - loss: 496.5111 - root_mean_squared_error: 22.2829 - val_loss: 447.8417 - val_root_mean_squared_error: 21.1263
# Epoch 159/250
# 98/98 [==============================] - 0s 5ms/step - loss: 492.8532 - root_mean_squared_error: 22.1808 - val_loss: 447.6375 - val_root_mean_squared_error: 21.1151
# Epoch 160/250
# 98/98 [==============================] - 1s 5ms/step - loss: 493.5835 - root_mean_squared_error: 22.2117 - val_loss: 462.8439 - val_root_mean_squared_error: 21.4161
# Epoch 161/250
# 98/98 [==============================] - 1s 5ms/step - loss: 493.6624 - root_mean_squared_error: 22.2386 - val_loss: 441.6994 - val_root_mean_squared_error: 20.9919
# Epoch 162/250
# 98/98 [==============================] - 1s 5ms/step - loss: 492.3952 - root_mean_squared_error: 22.1700 - val_loss: 442.1722 - val_root_mean_squared_error: 20.9890
# Epoch 163/250
# 98/98 [==============================] - 1s 5ms/step - loss: 490.8119 - root_mean_squared_error: 22.1500 - val_loss: 439.4293 - val_root_mean_squared_error: 20.9362
# Epoch 164/250
# 98/98 [==============================] - 1s 5ms/step - loss: 488.5542 - root_mean_squared_error: 22.0757 - val_loss: 441.9122 - val_root_mean_squared_error: 20.9752
# Epoch 165/250
# 98/98 [==============================] - 1s 5ms/step - loss: 487.3297 - root_mean_squared_error: 22.0822 - val_loss: 440.1896 - val_root_mean_squared_error: 20.9397
# Epoch 166/250
# 98/98 [==============================] - 1s 5ms/step - loss: 485.9304 - root_mean_squared_error: 22.0239 - val_loss: 436.3710 - val_root_mean_squared_error: 20.8535
# Epoch 167/250
# 98/98 [==============================] - 1s 5ms/step - loss: 484.6189 - root_mean_squared_error: 22.0204 - val_loss: 443.3196 - val_root_mean_squared_error: 20.9980
# Epoch 168/250
# 98/98 [==============================] - 1s 5ms/step - loss: 484.1764 - root_mean_squared_error: 21.9766 - val_loss: 444.7625 - val_root_mean_squared_error: 21.0171
# Epoch 169/250
# 98/98 [==============================] - 1s 5ms/step - loss: 483.5668 - root_mean_squared_error: 21.9624 - val_loss: 433.0120 - val_root_mean_squared_error: 20.7731
# Epoch 170/250
# 98/98 [==============================] - 1s 5ms/step - loss: 482.5278 - root_mean_squared_error: 21.9666 - val_loss: 432.1858 - val_root_mean_squared_error: 20.7453
# Epoch 171/250
# 98/98 [==============================] - 0s 5ms/step - loss: 480.1465 - root_mean_squared_error: 21.9111 - val_loss: 434.4775 - val_root_mean_squared_error: 20.7911
# Epoch 172/250
# 98/98 [==============================] - 1s 5ms/step - loss: 481.1545 - root_mean_squared_error: 21.9154 - val_loss: 428.1335 - val_root_mean_squared_error: 20.6618
# Epoch 173/250
# 98/98 [==============================] - 1s 5ms/step - loss: 477.8811 - root_mean_squared_error: 21.8600 - val_loss: 426.7296 - val_root_mean_squared_error: 20.6265
# Epoch 174/250
# 98/98 [==============================] - 1s 5ms/step - loss: 478.1692 - root_mean_squared_error: 21.8422 - val_loss: 435.9714 - val_root_mean_squared_error: 20.8148
# Epoch 175/250
# 98/98 [==============================] - 1s 5ms/step - loss: 474.7728 - root_mean_squared_error: 21.7547 - val_loss: 424.6822 - val_root_mean_squared_error: 20.5709
# Epoch 176/250
# 98/98 [==============================] - 1s 5ms/step - loss: 476.0881 - root_mean_squared_error: 21.8226 - val_loss: 423.0055 - val_root_mean_squared_error: 20.5356
# Epoch 177/250
# 98/98 [==============================] - 1s 5ms/step - loss: 473.0531 - root_mean_squared_error: 21.7211 - val_loss: 430.6654 - val_root_mean_squared_error: 20.6893
# Epoch 178/250
# 98/98 [==============================] - 0s 5ms/step - loss: 471.4644 - root_mean_squared_error: 21.7017 - val_loss: 421.4972 - val_root_mean_squared_error: 20.4940
# Epoch 179/250
# 98/98 [==============================] - 1s 5ms/step - loss: 472.3592 - root_mean_squared_error: 21.7641 - val_loss: 424.7982 - val_root_mean_squared_error: 20.5587
# Epoch 180/250
# 98/98 [==============================] - 1s 5ms/step - loss: 472.5548 - root_mean_squared_error: 21.7440 - val_loss: 429.5797 - val_root_mean_squared_error: 20.6543
# Epoch 181/250
# 98/98 [==============================] - 1s 5ms/step - loss: 468.9053 - root_mean_squared_error: 21.6228 - val_loss: 419.0395 - val_root_mean_squared_error: 20.4263
# Epoch 182/250
# 98/98 [==============================] - 0s 5ms/step - loss: 467.6786 - root_mean_squared_error: 21.6061 - val_loss: 415.3640 - val_root_mean_squared_error: 20.3493
# Epoch 183/250
# 98/98 [==============================] - 1s 5ms/step - loss: 469.3339 - root_mean_squared_error: 21.6486 - val_loss: 416.1420 - val_root_mean_squared_error: 20.3613
# Epoch 184/250
# 98/98 [==============================] - 0s 5ms/step - loss: 467.0676 - root_mean_squared_error: 21.5888 - val_loss: 413.5553 - val_root_mean_squared_error: 20.3042
# Epoch 185/250
# 98/98 [==============================] - 1s 5ms/step - loss: 465.7311 - root_mean_squared_error: 21.4954 - val_loss: 415.0099 - val_root_mean_squared_error: 20.3291
# Epoch 186/250
# 98/98 [==============================] - 0s 5ms/step - loss: 463.2422 - root_mean_squared_error: 21.5525 - val_loss: 414.9254 - val_root_mean_squared_error: 20.3272
# Epoch 187/250
# 98/98 [==============================] - 1s 5ms/step - loss: 464.5392 - root_mean_squared_error: 21.5004 - val_loss: 413.4944 - val_root_mean_squared_error: 20.2942
# Epoch 188/250
# 98/98 [==============================] - 0s 5ms/step - loss: 462.4827 - root_mean_squared_error: 21.4829 - val_loss: 416.6083 - val_root_mean_squared_error: 20.3596
# Epoch 189/250
# 98/98 [==============================] - 1s 5ms/step - loss: 462.6541 - root_mean_squared_error: 21.5050 - val_loss: 413.7025 - val_root_mean_squared_error: 20.2980
# Epoch 190/250
# 98/98 [==============================] - 0s 5ms/step - loss: 461.7174 - root_mean_squared_error: 21.4494 - val_loss: 412.0988 - val_root_mean_squared_error: 20.2540
# Epoch 191/250
# 98/98 [==============================] - 1s 5ms/step - loss: 457.7998 - root_mean_squared_error: 21.3722 - val_loss: 407.6755 - val_root_mean_squared_error: 20.1606
# Epoch 192/250
# 98/98 [==============================] - 0s 5ms/step - loss: 459.9398 - root_mean_squared_error: 21.4433 - val_loss: 407.3555 - val_root_mean_squared_error: 20.1472
# Epoch 193/250
# 98/98 [==============================] - 1s 5ms/step - loss: 457.0161 - root_mean_squared_error: 21.3919 - val_loss: 410.5547 - val_root_mean_squared_error: 20.2158
# Epoch 194/250
# 98/98 [==============================] - 0s 5ms/step - loss: 456.7957 - root_mean_squared_error: 21.3316 - val_loss: 408.0379 - val_root_mean_squared_error: 20.1541
# Epoch 195/250
# 98/98 [==============================] - 1s 5ms/step - loss: 456.5287 - root_mean_squared_error: 21.4043 - val_loss: 408.9799 - val_root_mean_squared_error: 20.1760
# Epoch 196/250
# 98/98 [==============================] - 1s 5ms/step - loss: 455.7637 - root_mean_squared_error: 21.3036 - val_loss: 411.8910 - val_root_mean_squared_error: 20.2362
# Epoch 197/250
# 98/98 [==============================] - 1s 5ms/step - loss: 453.5164 - root_mean_squared_error: 21.2906 - val_loss: 400.6061 - val_root_mean_squared_error: 19.9895
# Epoch 198/250
# 98/98 [==============================] - 1s 5ms/step - loss: 455.2400 - root_mean_squared_error: 21.3027 - val_loss: 412.9790 - val_root_mean_squared_error: 20.2576
# Epoch 199/250
# 98/98 [==============================] - 1s 5ms/step - loss: 450.0692 - root_mean_squared_error: 21.2258 - val_loss: 403.8279 - val_root_mean_squared_error: 20.0479
# Epoch 200/250
# 98/98 [==============================] - 0s 5ms/step - loss: 453.7957 - root_mean_squared_error: 21.3060 - val_loss: 401.3378 - val_root_mean_squared_error: 19.9966
# Epoch 201/250
# 98/98 [==============================] - 1s 5ms/step - loss: 451.3036 - root_mean_squared_error: 21.2133 - val_loss: 403.1158 - val_root_mean_squared_error: 20.0299
# Epoch 202/250
# 98/98 [==============================] - 1s 5ms/step - loss: 450.3817 - root_mean_squared_error: 21.2054 - val_loss: 400.9906 - val_root_mean_squared_error: 19.9832
# Epoch 203/250
# 98/98 [==============================] - 1s 5ms/step - loss: 449.2148 - root_mean_squared_error: 21.2186 - val_loss: 398.8553 - val_root_mean_squared_error: 19.9558
# Epoch 204/250
# 98/98 [==============================] - 1s 5ms/step - loss: 450.6566 - root_mean_squared_error: 21.2910 - val_loss: 398.2437 - val_root_mean_squared_error: 19.9179
# Epoch 205/250
# 98/98 [==============================] - 1s 5ms/step - loss: 448.0116 - root_mean_squared_error: 21.1621 - val_loss: 396.3683 - val_root_mean_squared_error: 19.8782
# Epoch 206/250
# 98/98 [==============================] - 1s 5ms/step - loss: 447.8368 - root_mean_squared_error: 21.1437 - val_loss: 395.1991 - val_root_mean_squared_error: 19.8440
# Epoch 207/250
# 98/98 [==============================] - 1s 5ms/step - loss: 446.7598 - root_mean_squared_error: 21.1540 - val_loss: 394.2326 - val_root_mean_squared_error: 19.8292
# Epoch 208/250
# 98/98 [==============================] - 1s 5ms/step - loss: 443.8674 - root_mean_squared_error: 21.0232 - val_loss: 399.1239 - val_root_mean_squared_error: 19.9282
# Epoch 209/250
# 98/98 [==============================] - 1s 5ms/step - loss: 444.1124 - root_mean_squared_error: 21.1116 - val_loss: 392.7856 - val_root_mean_squared_error: 19.7866
# Epoch 210/250
# 98/98 [==============================] - 1s 5ms/step - loss: 442.8184 - root_mean_squared_error: 21.0407 - val_loss: 392.3321 - val_root_mean_squared_error: 19.7708
# Epoch 211/250
# 98/98 [==============================] - 1s 5ms/step - loss: 443.8540 - root_mean_squared_error: 21.0744 - val_loss: 394.9825 - val_root_mean_squared_error: 19.8334
# Epoch 212/250
# 98/98 [==============================] - 1s 5ms/step - loss: 441.4625 - root_mean_squared_error: 21.0158 - val_loss: 391.9044 - val_root_mean_squared_error: 19.7612
# Epoch 213/250
# 98/98 [==============================] - 1s 5ms/step - loss: 442.7696 - root_mean_squared_error: 20.9988 - val_loss: 397.9765 - val_root_mean_squared_error: 19.9017
# Epoch 214/250
# 98/98 [==============================] - 1s 5ms/step - loss: 441.2034 - root_mean_squared_error: 21.0046 - val_loss: 389.1697 - val_root_mean_squared_error: 19.7008
# Epoch 215/250
# 98/98 [==============================] - 1s 5ms/step - loss: 441.4780 - root_mean_squared_error: 21.0146 - val_loss: 389.4981 - val_root_mean_squared_error: 19.7048
# Epoch 216/250
# 98/98 [==============================] - 1s 5ms/step - loss: 441.1525 - root_mean_squared_error: 21.0188 - val_loss: 388.5568 - val_root_mean_squared_error: 19.6755
# Epoch 217/250
# 98/98 [==============================] - 1s 5ms/step - loss: 440.8355 - root_mean_squared_error: 21.0248 - val_loss: 397.3459 - val_root_mean_squared_error: 19.8724
# Epoch 218/250
# 98/98 [==============================] - 1s 5ms/step - loss: 440.9673 - root_mean_squared_error: 21.0219 - val_loss: 395.5866 - val_root_mean_squared_error: 19.8382
# Epoch 219/250
# 98/98 [==============================] - 1s 5ms/step - loss: 438.9133 - root_mean_squared_error: 20.9415 - val_loss: 391.3021 - val_root_mean_squared_error: 19.7374
# Epoch 220/250
# 98/98 [==============================] - 0s 5ms/step - loss: 437.3363 - root_mean_squared_error: 20.8740 - val_loss: 388.5070 - val_root_mean_squared_error: 19.6694
# Epoch 221/250
# 98/98 [==============================] - 1s 5ms/step - loss: 438.3052 - root_mean_squared_error: 20.9269 - val_loss: 397.5490 - val_root_mean_squared_error: 19.8777
# Epoch 222/250
# 98/98 [==============================] - 1s 5ms/step - loss: 435.8903 - root_mean_squared_error: 20.8802 - val_loss: 385.9828 - val_root_mean_squared_error: 19.6130
# Epoch 223/250
# 98/98 [==============================] - 1s 5ms/step - loss: 434.6256 - root_mean_squared_error: 20.8489 - val_loss: 385.6768 - val_root_mean_squared_error: 19.6015
# Epoch 224/250
# 98/98 [==============================] - 1s 5ms/step - loss: 433.5345 - root_mean_squared_error: 20.7776 - val_loss: 386.5316 - val_root_mean_squared_error: 19.6253
# Epoch 225/250
# 98/98 [==============================] - 1s 5ms/step - loss: 433.9515 - root_mean_squared_error: 20.8130 - val_loss: 387.8394 - val_root_mean_squared_error: 19.6486
# Epoch 226/250
# 98/98 [==============================] - 1s 5ms/step - loss: 433.3197 - root_mean_squared_error: 20.8134 - val_loss: 381.8648 - val_root_mean_squared_error: 19.5189
# Epoch 227/250
# 98/98 [==============================] - 0s 5ms/step - loss: 433.7747 - root_mean_squared_error: 20.7760 - val_loss: 384.5538 - val_root_mean_squared_error: 19.5670
# Epoch 228/250
# 98/98 [==============================] - 1s 5ms/step - loss: 431.1511 - root_mean_squared_error: 20.7424 - val_loss: 391.5776 - val_root_mean_squared_error: 19.7308
# Epoch 229/250
# 98/98 [==============================] - 1s 5ms/step - loss: 430.1078 - root_mean_squared_error: 20.7541 - val_loss: 383.6334 - val_root_mean_squared_error: 19.5476
# Epoch 230/250
# 98/98 [==============================] - 1s 5ms/step - loss: 431.8518 - root_mean_squared_error: 20.7862 - val_loss: 381.2372 - val_root_mean_squared_error: 19.4877
# Epoch 231/250
# 98/98 [==============================] - 1s 5ms/step - loss: 431.6693 - root_mean_squared_error: 20.7211 - val_loss: 378.7459 - val_root_mean_squared_error: 19.4341
# Epoch 232/250
# 98/98 [==============================] - 1s 5ms/step - loss: 428.9967 - root_mean_squared_error: 20.7624 - val_loss: 394.8512 - val_root_mean_squared_error: 19.8059
# Epoch 233/250
# 98/98 [==============================] - 1s 5ms/step - loss: 432.3178 - root_mean_squared_error: 20.8268 - val_loss: 382.0422 - val_root_mean_squared_error: 19.5046
# Epoch 234/250
# 98/98 [==============================] - 1s 5ms/step - loss: 428.5951 - root_mean_squared_error: 20.6679 - val_loss: 379.8334 - val_root_mean_squared_error: 19.4567
# Epoch 235/250
# 98/98 [==============================] - 1s 5ms/step - loss: 428.6010 - root_mean_squared_error: 20.6789 - val_loss: 378.3291 - val_root_mean_squared_error: 19.4162
# Epoch 236/250
# 98/98 [==============================] - 1s 5ms/step - loss: 427.4607 - root_mean_squared_error: 20.6242 - val_loss: 378.8463 - val_root_mean_squared_error: 19.4286
# Epoch 237/250
# 98/98 [==============================] - 0s 5ms/step - loss: 424.1063 - root_mean_squared_error: 20.5903 - val_loss: 379.5334 - val_root_mean_squared_error: 19.4421
# Epoch 238/250
# 98/98 [==============================] - 1s 5ms/step - loss: 424.8292 - root_mean_squared_error: 20.5859 - val_loss: 378.5576 - val_root_mean_squared_error: 19.4147
# Epoch 239/250
# 98/98 [==============================] - 1s 5ms/step - loss: 424.2316 - root_mean_squared_error: 20.5760 - val_loss: 375.5787 - val_root_mean_squared_error: 19.3495
# Epoch 240/250
# 98/98 [==============================] - 1s 5ms/step - loss: 425.6374 - root_mean_squared_error: 20.5881 - val_loss: 375.8331 - val_root_mean_squared_error: 19.3561
# Epoch 241/250
# 98/98 [==============================] - 1s 5ms/step - loss: 423.6738 - root_mean_squared_error: 20.5330 - val_loss: 379.5888 - val_root_mean_squared_error: 19.4384
# Epoch 242/250
# 98/98 [==============================] - 1s 5ms/step - loss: 423.0450 - root_mean_squared_error: 20.5382 - val_loss: 375.6673 - val_root_mean_squared_error: 19.3449
# Epoch 243/250
# 98/98 [==============================] - 1s 5ms/step - loss: 423.3720 - root_mean_squared_error: 20.5333 - val_loss: 376.8541 - val_root_mean_squared_error: 19.3736
# Epoch 244/250
# 98/98 [==============================] - 1s 5ms/step - loss: 423.0100 - root_mean_squared_error: 20.5431 - val_loss: 386.5182 - val_root_mean_squared_error: 19.6016
# Epoch 245/250
# 98/98 [==============================] - 1s 5ms/step - loss: 423.5735 - root_mean_squared_error: 20.5123 - val_loss: 376.0219 - val_root_mean_squared_error: 19.3543
# Epoch 246/250
# 98/98 [==============================] - 1s 5ms/step - loss: 421.1649 - root_mean_squared_error: 20.4627 - val_loss: 376.0824 - val_root_mean_squared_error: 19.3501
# Epoch 247/250
# 98/98 [==============================] - 1s 5ms/step - loss: 420.9443 - root_mean_squared_error: 20.4719 - val_loss: 373.6855 - val_root_mean_squared_error: 19.2916
# Epoch 248/250
# 98/98 [==============================] - 1s 5ms/step - loss: 419.0667 - root_mean_squared_error: 20.5529 - val_loss: 373.9630 - val_root_mean_squared_error: 19.2974
# Epoch 249/250
# 98/98 [==============================] - 1s 5ms/step - loss: 419.3637 - root_mean_squared_error: 20.4346 - val_loss: 371.6158 - val_root_mean_squared_error: 19.2447
# Epoch 250/250
# 98/98 [==============================] - 1s 5ms/step - loss: 419.1762 - root_mean_squared_error: 20.4613 - val_loss: 376.2670 - val_root_mean_squared_error: 19.3525

# %%
loss2 = history2.history['loss']
val_loss2 = history2.history['val_loss']

epochs = range(len(loss2))

plt.figure(figsize=(10,6))
plt.grid(True) 
plt.plot(epochs, np.log10(loss2),'black',lw=0.9, label='Training Error')
plt.plot(epochs, np.log10(val_loss2), 'orange',lw=0.9, label='Validation Error')
plt.ylabel("Log(Error)",fontsize=20)
plt.xlabel("# Epochs",fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('Training and validation Error', fontsize=20)
plt.legend(prop={"size":20})
  

plt.show()

# %%
# predictions2 es el vector de RUL estimado de los motores del test ordenados en orden descendente a partir de su rul verdadero (dataset FD002+FD004)
predictions2 = cnnturbofan2.predict(f_maps_test_f2f4)

# %%
leng = range(len(predictions2))

plt.figure(figsize=(8,8))
plt.grid(True) 
# predictions2 es el vector de RUL estimado de los motores del test ordenados en orden descendente a partir de su rul verdadero (dataset FD002+FD004)
plt.plot(leng, predictions2[::-1], 'bo',lw=0.9, label='predict RUL value')
# r_test_f2f4 es el vector de RUL verdadero ordenado en orden descendente del dataset FD002+FD004
plt.plot(leng, r_test_f2f4[::-1], 'ro',lw=0.9, label='true RUL value')
plt.fill_between([265,0],[120,120],facecolor='green',alpha=0.2)
plt.fill_between([364,265],[120,120],facecolor='yellow',alpha=0.2)
plt.fill_between([507,364],[120,120],facecolor='red',alpha=0.2)
plt.ylabel('RUL',fontsize=18)
plt.xlabel('Motor',fontsize=18)
plt.title('True and predict',fontsize=20)
plt.legend(prop={"size":15})
  

plt.show()

# %%
r_test_f2f4_early = r_test_f2f4[r_test_f2f4 <= 40]
predictions_early_2 = predictions2[:(len(r_test_f2f4_early))]
# _____________________________________

r_test_f2f4_late = r_test_f2f4[r_test_f2f4 > 80]
predictions_late_2 = predictions2[(len(predictions2) - len(r_test_f2f4_late)):]
# _____________________________________

r_test_f2f4_mid = r_test_f2f4[(r_test_f2f4 > 40) & (r_test_f2f4 <= 80)]
predictions_mid_2 = predictions2[(len(r_test_f2f4_early)):(len(predictions2) - len(r_test_f2f4_late))]

# ____________________________________

rmse_2 = sqrt(mean_squared_error(predictions2, r_test_f2f4))
rmse_early_2 = sqrt(mean_squared_error(predictions_early_2,r_test_f2f4_early))
rmse_mid_2 = sqrt(mean_squared_error(predictions_mid_2,r_test_f2f4_mid))
rmse_late_2 = sqrt(mean_squared_error(predictions_late_2,r_test_f2f4_late))


print(rmse_2)
print(rmse_early_2)
print(rmse_mid_2)
print(rmse_late_2)
# Out:
# 19.390859483429917
# 17.579718532141698
# 28.18221640178565
# 15.99035723098021

# %%
arch_fd001 = open("FD001+FD003_MSE_turbofan[13].txt","a")
arch_fd001.write(str(round(rmse,3))+ " " + str(round(rmse_early,3))+ " " + str(round(rmse_mid,3))+ " " + str(round(rmse_late,3))+ " " + str(BATCH_SIZE_T) + " " + str(EPOCHS_MAX) + " " + OPTIM + " " + str(W_H_FD001) + '\n')
arch_fd001.close()
arch_fd002 = open("FD002+FD004_MSE_turbofan[13].txt","a")
arch_fd002.write(str(round(rmse_2,3))+ " " +str(round(rmse_early_2,3))+ " " +str(round(rmse_mid_2,3))+ " " +str(round(rmse_late_2,3)) + " " + str(BATCH_SIZE_T) + " " + str(EPOCHS_MAX) + " " + OPTIM +  " " + str(W_H_FD001) + '\n')
arch_fd002.close()

# %% [markdown]
# Traspaso de arrays a formato JSON para construir con posterioridad sus gráficos junto con otros modelos.

# %%
#list to json
import codecs, json 

b = predictions.tolist() # nested lists with same data, indices
file_path = "predictions_Ba_FD001+FD003_"+ str(BATCH_SIZE_T) + "_" + str(EPOCHS_MAX) + "_" + str(W_H_FD001) + ".json" ## your path variable
json.dump(b, codecs.open(file_path, 'w', encoding='utf-8'), separators=(',', ':'), sort_keys=True, indent=4) ### this saves the array in .json format

# %%
 # nested lists with same data, indices
file_path = "losstrain_Ba_FD001+FD003_"+ str(BATCH_SIZE_T) + "_" + str(EPOCHS_MAX) + "_" + str(W_H_FD001) + ".json" ## your path variable
json.dump(loss, codecs.open(file_path, 'w', encoding='utf-8'), separators=(',', ':'), sort_keys=True, indent=4) ### this saves the array in .json format

# %%
file_path = "lossval_Ba_FD001+FD003_"+ str(BATCH_SIZE_T) + "_" + str(EPOCHS_MAX) + "_" + str(W_H_FD001) + ".json" ## your path variable
json.dump(val_loss, codecs.open(file_path, 'w', encoding='utf-8'), separators=(',', ':'), sort_keys=True, indent=4) ### this saves the array in .json format

# %%
b = predictions2.tolist() # nested lists with same data, indices
file_path = "predictions_Ba_FD002+FD004_"+ str(BATCH_SIZE_T) + "_" + str(EPOCHS_MAX) + "_" + str(W_H_FD001) + ".json" ## your path variable
json.dump(b, codecs.open(file_path, 'w', encoding='utf-8'), separators=(',', ':'), sort_keys=True, indent=4) ### this saves the array in .json format

# %%
file_path = "losstrain_Ba_FD002+FD004_"+ str(BATCH_SIZE_T) + "_" + str(EPOCHS_MAX) + "_" + str(W_H_FD001) + ".json" ## your path variable
json.dump(loss2, codecs.open(file_path, 'w', encoding='utf-8'), separators=(',', ':'), sort_keys=True, indent=4) ### this saves the array in .json format

# %%
file_path = "lossval_Ba_FD002+FD004_"+ str(BATCH_SIZE_T) + "_" + str(EPOCHS_MAX) + "_" + str(W_H_FD001) + ".json" ## your path variable
json.dump(val_loss2, codecs.open(file_path, 'w', encoding='utf-8'), separators=(',', ':'), sort_keys=True, indent=4) ### this saves the array in .json format

# %%
#json to list

obj_text = codecs.open(file_path, 'r', encoding='utf-8').read()
b_new = json.loads(obj_text)
a_new = np.array(b_new)

# %%
b = r_test_f2f4.tolist()
file_path = "predicts24.json" ## your path variable
json.dump(b, codecs.open(file_path, 'w', encoding='utf-8'), separators=(',', ':'), sort_keys=True, indent=4) ### this saves the array in .json format

# %%
b = r_test_f1f3.tolist()
file_path = "predicts13.json" ## your path variable
json.dump(b, codecs.open(file_path, 'w', encoding='utf-8'), separators=(',', ':'), sort_keys=True, indent=4) ### this saves the array in .json format
